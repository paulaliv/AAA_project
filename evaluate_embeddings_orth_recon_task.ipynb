# %%
import torch
import numpy as np
import pandas as pd

emb = torch.load(
    "embeddings_orth_loss/fold_4_embeddings.pt"
)

tissue_emb = emb["epoch99"]["tissue"]
plasma_emb = emb["epoch99"]["plasma"]


patients = sorted(
    set(tissue_emb.keys()) &
    set(plasma_emb.keys())
)

print(len(patients))
# Out:
# 10

# %%
print(tissue_emb.keys())
# Out:
# dict_keys(['Sample 20', 'Sample 24', 'Sample 30', 'Sample 36', 'Sample 39', 'Sample 45', 'Sample 55', 'Sample 72', 'Sample 77', 'Sample 90'])

# %%
relevant =pd.read_csv('clinical_labels.csv')

# %%
relevant.columns
# Out:
# Index(['Unnamed: 0', 'Sample_index', 'Measurement_index', 'Patiëntnummer',
#        'Institute', 'Inclusion', 'Date_surgery', 'Date_processed', 'Pathology',
#        'SimplePathology', 'Sex', 'Age', 'BMI', 'Size_AA', 'Smoking',
#        'Years_to_quitting', 'Diabetes', 'DM_meds', 'Hypertension',
#        'HyperCholstero', 'Previous_vascu_surgery', 'Renal_dysfunction',
#        'Clinical presentation', 'Angio related familial history',
#        'Previous growth (mm/year)', 'Type Aneurysms', 'Type surgery', 'Remark',
#        'In_Tara_patientfile', 'From BioBank', 'In PAREL biobank'],
#       dtype='object')

# %%
relevant['Size_AA'].head(20)
# Out:
# 0     NaN
# 1      44
# 2      63
# 3     NaN
# 4      90
# 5      61
# 6      50
# 7      64
# 8     NaN
# 9      60
# 10     55
# 11     67
# 12     40
# 13     52
# 14     70
# 15     63
# 16     61
# 17     58
# 18      ?
# 19     62
# Name: Size_AA, dtype: object

# %%
relevant['Size_AA'] = relevant['Size_AA'].replace('?', np.nan).astype(float)

# %%
float(relevant['Size_AA']).describe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 float(relevant['Size_AA']).describe()
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/series.py:251, in _coerce_method.<locals>.wrapper(self)
#     243     warnings.warn(
#     244         f"Calling {converter.__name__} on a single element Series is "
#     245         "deprecated and will raise a TypeError in the future. "
#    (...)
#     248         stacklevel=find_stack_level(),
#     249     )
#     250     return converter(self.iloc[0])
# --> 251 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'float'>

# %%
#relevant['Size_AA'] = [float(x) for x in relevant['Size_AA']]
relevant['Size_AA_Cat'] = pd.cut(
    relevant['Size_AA'],
    bins=[-float('inf'), 50, 60, 70, 80, float('inf')],
    labels=[0, 1, 2, 3, 4],
    right=False
)
size_mapping = {
    0: "40–<50 mm",
    1: "50–<60 mm",
    2: "60–<70 mm",
    3: "70–<80 mm",
    4: "≥80 mm",
    'na' : 'Unknown'
}

# %%
relevant['Size_AA_Cat'].isna().sum()
# Out:
# np.int64(4)

# %%
clinical_size_mapping = dict(
    zip(
        relevant['Sample_index'],
        relevant['Size_AA_Cat']
    )
)

# %%
clinical_mapping = dict(
    zip(
        relevant['Sample_index'],
        relevant['Clinical presentation']
    )
)

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.lines import Line2D
def plot(pca_df, proj = False, epoch=0):
    patients = sorted(
    set(pca_df["patient"])
    )

    # Create a color mapping for patients
    colors = cm.get_cmap("tab20", len(patients))
    patient_colors = {
        patient: colors(i)
        for i, patient in enumerate(patients)
    }

    # Shape = clinical presentation
    clinical_markers = {
        "Unknown": "o",
        "Symptomatic": "s",
        "Asymptomatic": "D",
        "Ruptured": "X"
    }

    plt.figure(figsize=(9,6))



    for patient in patients:

        color = patient_colors[patient]

        tissue = pca_df[
        (pca_df["patient"] == patient) &
        (pca_df["modality"] == "Tissue")
        ].iloc[0]

        plasma = pca_df[
        (pca_df["patient"] == patient) &
        (pca_df["modality"] == "Plasma")
        ].iloc[0]

        t = tissue[["PC1", "PC2"]].values
        p = plasma[["PC1", "PC2"]].values




        clinical = clinical_mapping.get(patient, "Unknown")
        if clinical == 'Ruptured':
            print(f' Patient {patient}has rupture label!')
        if clinical == 'Symptomatic':
            print(f' Patient {patient} has label symptomatic')

        marker = clinical_markers.get(clinical, "o")


         # Tissue = filled
        plt.scatter(
            t[0],
            t[1],
            marker=marker,
            color=color,
            label="Tissue" if patient == patients[0] else ""
        )

        # Plasma = open
        plt.scatter(
            p[0],
            p[1],
            marker=marker,
            facecolors="none",
            edgecolors=color,
            label="Plasma" if patient == patients[0] else ""
        )

        # Connect tissue-plasma pair
        plt.plot(
            [t[0], p[0]],
            [t[1], p[1]],
            color=color,
            alpha=0.3
        )
           # -------------------------
    # Legends
    # -------------------------

    modality_legend = [
        Line2D(
            [0], [0],
            marker="o",
            color="black",
            markerfacecolor="black",
            linestyle="None",
            markersize=7,
            label="Tissue"
        ),
        Line2D(
            [0], [0],
            marker="o",
            color="black",
            markerfacecolor="none",
            linestyle="None",
            markersize=7,
            label="Plasma"
        )
    ]

    clinical_legend = [
        Line2D(
            [0], [0],
            marker=marker,
            color="black",
            linestyle="None",
            markersize=8,
            label=clinical
        )
        for clinical, marker in clinical_markers.items()
    ]

    legend1 = plt.legend(
        handles=modality_legend,
        title="Modality",
        loc="upper left",
        bbox_to_anchor=(1.02, 1)
    )

    plt.gca().add_artist(legend1)

    plt.legend(
        handles=clinical_legend,
        title="Clinical presentation",
        loc="upper left",
        bbox_to_anchor=(1.02, 0.65)
    )
    if proj:
        emb_type = "projected embedding"
    else:
        emb_type = "encoded embedding"

    plt.title(
        f"Patient-wise tissue-plasma {emb_type} alignment "
        f"after {epoch} epochs"
    )

    plt.xlabel("PC1")
    plt.ylabel("PC2")
    plt.tight_layout()

    plt.show()






    # plt.savefig(f'embeddings/plots/embeddings_fold_{fold}_{epoch}_{emb_type}.png',
    #     bbox_inches="tight")

# %%
def plot_2(pca_df,proj = False, epoch=0):
    patients = sorted(
    set(pca_df["patient"])
    )

    # Create a color mapping for patients
    colors = cm.get_cmap("tab20", len(patients))
    patient_colors = {
        patient: colors(i)
        for i, patient in enumerate(patients)
    }

    size_colors = cm.get_cmap("tab10", 6)
    size_labels = {
        0: "40–<50 mm",
        1: "50–<60 mm",
        2: "60–<70 mm",
        3: "70–<80 mm",
        4: "≥80 mm",
        5: 'Unknown'
    }




    fig = plt.figure(figsize=(9, 6))
    gs = fig.add_gridspec(
        1, 2,
        width_ratios=[4, 1.5],
        wspace=0.05
    )

    ax = fig.add_subplot(gs[0])
    legend_ax = fig.add_subplot(gs[1])

    legend_ax.axis("off")



    for patient in patients:

        color = patient_colors[patient]

        tissue = pca_df[
        (pca_df["patient"] == patient) &
        (pca_df["modality"] == "Tissue")
        ].iloc[0]

        plasma = pca_df[
        (pca_df["patient"] == patient) &
        (pca_df["modality"] == "Plasma")
        ].iloc[0]

        t = tissue[["PC1", "PC2"]].values
        p = plasma[["PC1", "PC2"]].values

        size_cat = relevant.loc[
        relevant["Sample_index"] == patient,
        "Size_AA_Cat"
        ].iloc[0]

        if pd.isna(size_cat):
            size_cat = 5
        else:
            size_cat = int(size_cat)

        size_color = size_colors(int(size_cat))

                # Size ring around tissue
        ax.scatter(
            t[0],
            t[1],
            marker="o",
            s=180,
            facecolors="none",
            edgecolors=size_color,
            linewidths=2.5
        )

        # Patient-colored tissue point
        ax.scatter(
            t[0],
            t[1],
            marker="o",
            s=50,
            color=color
        )

                # Size ring around plasma
        ax.scatter(
            p[0],
            p[1],
            marker="o",
            s=180,
            facecolors="none",
            edgecolors=size_color,
            linewidths=2.5
        )

        # Patient-colored plasma point
        ax.scatter(
            p[0],
            p[1],
            marker="o",
            s=50,
            facecolors="none",
            edgecolors=color,
            linewidths=1.5
        )


        # Connect tissue-plasma pair
        ax.plot(
            [t[0], p[0]],
            [t[1], p[1]],
            color=color,
            alpha=0.3
        )
           # -------------------------
    # Legends
    # -------------------------
        # -------------------------
    # Size legend
    # -------------------------
    size_legend = [
        Line2D(
            [0], [0],
            marker="o",
            linestyle="None",
            markerfacecolor="none",
            markeredgecolor=size_colors(i),
            markersize=10,
            markeredgewidth=2.5,
            label=size_labels[i]
        )
        for i in range(6)
    ]
    legend_size = legend_ax.legend(
    handles=size_legend,
    title="Aneurysm size",
    loc="upper left",
    bbox_to_anchor=(0, 0.60),
    frameon=True
)

    # -------------------------
    # Modality legend
    # -------------------------
    modality_legend = [
        Line2D(
            [0], [0],
            marker="o",
            color="black",
            markerfacecolor="black",
            linestyle="None",
            markersize=7,
            label="Tissue"
        ),
        Line2D(
            [0], [0],
            marker="^",
            color="black",
            markerfacecolor="none",
            linestyle="None",
            markersize=8,
            label="Plasma"
        )
    ]

    # Put both legends in the dedicated legend area
    legend_ax.legend(
        handles=modality_legend,
        title="Modality",
        loc="upper left",
        frameon=True
    )


    legend_ax.legend(
            handles=size_legend,
            title="Aneurysm size",
            loc="upper left",
            bbox_to_anchor=(0, 0.65),
            frameon=True
        )


    if proj:
        emb_type = "projected embedding"
    else:
        emb_type = "encoded embedding"

    ax.set_title(
        f"Patient-wise tissue-plasma {emb_type} alignment "
        f"after {epoch} epochs"
    )

    ax.set_xlabel("PC1")
    ax.set_ylabel("PC2")
    plt.show()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.lines import Line2D
def plot_3(pca_df, proj = False, epoch=0):
    patients = sorted(
    set(pca_df["patient"])
    )

    # Color mapping for folds
    folds = sorted(pca_df["fold"].unique())
    colors = cm.get_cmap("tab10", len(folds))

    fold_colors = {
        fold: colors(i)
        for i, fold in enumerate(folds)
    }

    plt.figure(figsize=(9, 6))

    for patient in patients:

        tissue = pca_df[
            (pca_df["patient"] == patient) &
            (pca_df["modality"] == "Tissue")
        ].iloc[0]

        plasma = pca_df[
            (pca_df["patient"] == patient) &
            (pca_df["modality"] == "Plasma")
        ].iloc[0]

        t = tissue[["PC1", "PC2"]].values
        p = plasma[["PC1", "PC2"]].values

        # Color based on fold
        fold = tissue["fold"]
        color = fold_colors[fold]
        print(patient, fold, color)


         # Tissue = filled
        plt.scatter(
            t[0],
            t[1],
            color=color
        )

        # Plasma = open
        plt.scatter(
            p[0],
            p[1],
            facecolors="none",
            edgecolors=color
        )

        # Connect tissue-plasma pair
        plt.plot(
            [t[0], p[0]],
            [t[1], p[1]],
            color=color,
            alpha=0.3
        )
           # -------------------------
    # Legends
    # -------------------------

    modality_legend = [
        Line2D(
            [0], [0],
            marker="o",
            color="black",
            markerfacecolor="black",
            linestyle="None",
            markersize=7,
            label="Tissue"
        ),
        Line2D(
            [0], [0],
            marker="o",
            color="black",
            markerfacecolor="none",
            linestyle="None",
            markersize=7,
            label="Plasma"
        )
    ]

     # Fold
    fold_legend = [
        Line2D(
            [0], [0],
            marker="o",
            color=fold_colors[fold],
            markerfacecolor=fold_colors[fold],
            linestyle="None",
            markersize=8,
            label=f"Fold {fold}"
        )
        for fold in folds
    ]
    legend1 = plt.legend(
    handles=modality_legend,
    title="Modality",
    loc="upper left",
    bbox_to_anchor=(1.02, 1)
    )

    plt.gca().add_artist(legend1)

    plt.legend(
        handles=fold_legend,
        title="Fold",
        loc="upper left",
        bbox_to_anchor=(1.02, 0.65)
    )

    plt.subplots_adjust(right=0.75)


    if proj:
        emb_type = "projected embedding"
    else:
        emb_type = "encoded embedding"

    plt.title(
        f"Patient-wise tissue-plasma {emb_type} alignment "
        f"after {epoch} epochs"
    )

    plt.xlabel("PC1")
    plt.ylabel("PC2")
    plt.tight_layout()

    plt.show()






    # plt.savefig(f'embeddings/plots/embeddings_fold_{fold}_{epoch}_{emb_type}.png',
    #     bbox_inches="tight")

# %%
def compute_PCA(plasma_emb, tissue_emb):
    X = []
    labels = []
    modalities = []
    patients = sorted(
        set(tissue_emb.keys()) &
        set(plasma_emb.keys())
    )

    for patient in patients:

        X.append(
            tissue_emb[patient].numpy()
        )
        labels.append(patient)
        modalities.append("Tissue")


        X.append(
            plasma_emb[patient].numpy()
        )
        labels.append(patient)
        modalities.append("Plasma")


    X = np.stack(X)
    pca = PCA(
        n_components=2
    )

    X_pca = pca.fit_transform(X)
    pca_df = pd.DataFrame({
    "patient": labels,
    "modality": modalities,
    "PC1": X_pca[:,0],
    "PC2": X_pca[:,1]
})
    return pca, pca_df

# %%
def compute_PCA_1(plasma_emb, tissue_emb):
    X = []
    labels = []
    modalities = []
    patients = sorted(
        set(tissue_emb.keys()) &
        set(plasma_emb.keys())
    )

    for patient in patients:

        X.append(
            tissue_emb[patient].numpy()
        )
        labels.append(patient)
        modalities.append("Tissue")


        X.append(
            plasma_emb[patient].numpy()
        )
        labels.append(patient)
        modalities.append("Plasma")


    X = np.stack(X)
    pca = PCA(
        n_components=2
    )

    X_pca = pca.fit_transform(X)
    pca_df = pd.DataFrame({
    "patient": labels,
    "modality": modalities,
    "PC1": X_pca[:,0],
    "PC2": X_pca[:,1]
})
    return pca, pca_df

# %%
def paired_distances_per_pc(pca_df):

    pc_cols = [c for c in pca_df.columns if c.startswith("PC")]

    results = []

    for pc in pc_cols:

        distances = []

        for patient in pca_df["patient"].unique():

            tissue = pca_df[
                (pca_df.patient == patient) &
                (pca_df.modality == "Tissue")
            ][pc].values[0]

            plasma = pca_df[
                (pca_df.patient == patient) &
                (pca_df.modality == "Plasma")
            ][pc].values[0]

            distances.append(abs(tissue - plasma))

        results.append({
            "PC": pc,
            "mean_distance": np.mean(distances),
            "std_distance": np.std(distances)
        })

    return pd.DataFrame(results)

# %%
def modality_separation(pca_df):

    pc_cols = [c for c in pca_df.columns if c.startswith("PC")]

    results = []

    for pc in pc_cols:

        tissue_values = pca_df[
            pca_df["modality"] == "Tissue"
        ][pc]

        plasma_values = pca_df[
            pca_df["modality"] == "Plasma"
        ][pc]

        separation = abs(
            tissue_values.mean() -
            plasma_values.mean()
        )

        results.append({
            "PC": pc,
            "modality_separation": separation,
            "tissue_mean": tissue_values.mean(),
            "plasma_mean": plasma_values.mean()
        })

    return pd.DataFrame(results)

# %%
def visualize_embeddings(proj=False, trained = True):
    all_pc_distances = []
    all_pc_separations = []
    all_variance =[]
    pc_all_folds ={}

    for fold in range(5):
        if proj:
            emb = torch.load(
            f"embeddings_orth_recon_task/fold_{fold}_embeddings_proj.pt"
            )
            best_emb = torch.load(
                f"embeddings_orth_recon_task/fold_{fold}_best_embeddings_proj.pt"
            )
            
            tissue_emb_0 = emb["epoch0"]["tissue"]
            plasma_emb_0 = emb["epoch0"]["plasma"]
    
            tissue_emb_99 = best_emb["tissue"]
            plasma_emb_99 = best_emb["plasma"]
            print(f'best emb saved at epoch {best_emb["epoch"]}')
            
        else:
            emb = torch.load(
            f"embeddings_orth_loss/fold_{fold}_embeddings.pt"
            )
            

            tissue_emb_0 = emb["epoch0"]["tissue"]
            plasma_emb_0 = emb["epoch0"]["plasma"]
    
            tissue_emb_99 = emb["epoch99"]["tissue"]
            plasma_emb_99 = emb["epoch99"]["plasma"]
            
    
        pca_0, pca_0_df = compute_PCA(plasma_emb_0['shared'], tissue_emb_0['shared'])
        pca_99, pca_99_df = compute_PCA(plasma_emb_99['shared'], tissue_emb_99['shared'])
        
        
        from sklearn.metrics import roc_auc_score
        if trained == True:
            pca_99_df['fold']= fold
            pc_all_folds[fold] = pca_99_df.copy()
            for pc in ["PC1", "PC2"]:
    
                values = pca_99_df[pc].values
    
                labels = (
                    pca_99_df["modality"] == "Plasma"
                ).astype(int)
    
                auc = roc_auc_score(labels, values)
    
                print(pc, auc)
    
    
            distance = paired_distances_per_pc(pca_99_df)
            distance["fold"] = fold
            print(f'Distances Fold {fold}')
            print(distance)
    
            all_pc_distances.append(distance)
    
            separation = modality_separation(pca_99_df)
            separation["fold"] = fold
    
            print(f"Fold {fold} separation")
            print(separation)
            all_pc_separations.append(separation)
    
            explained_variance = pd.DataFrame({
            "PC": [f"PC{i+1}" for i in range(len(pca_99.explained_variance_ratio_))],
            "explained_variance": pca_99.explained_variance_ratio_,
            "fold": fold
            })
    
            all_variance.append(explained_variance)
    
            plt.bar(
            range(1,3),
            pca_99.explained_variance_ratio_,
            )
            plt.title(f'explained variance ratio for fold {fold}')
            plt.xlabel("PC")
            plt.ylabel("Explained variance")
            plt.show()
            plot(pca_0_df, proj=proj,epoch=0)
            plot(pca_99_df,proj=proj,epoch=99)

            plot_2(pca_0_df, proj=proj,epoch=0)
            plot_2(pca_99_df, proj=proj,epoch=99)

    
        else:
            pca_0_df['fold']= fold
            pc_all_folds[fold] = pca_0_df.copy()
            for pc in ["PC1", "PC2"]:
    
                values = pca_0_df[pc].values
    
                labels = (
                    pca_0_df["modality"] == "Plasma"
                ).astype(int)
    
                auc = roc_auc_score(labels, values)
    
                print(pc, auc)
    
    
            distance = paired_distances_per_pc(pca_0_df)
            distance["fold"] = fold
            print(f'Distances Fold {fold}')
            print(distance)
    
            all_pc_distances.append(distance)
    
            separation = modality_separation(pca_0_df)
            separation["fold"] = fold
    
            print(f"Fold {fold} separation")
            print(separation)
            all_pc_separations.append(separation)
    
            explained_variance = pd.DataFrame({
            "PC": [f"PC{i+1}" for i in range(len(pca_0.explained_variance_ratio_))],
            "explained_variance": pca_0.explained_variance_ratio_,
            "fold": fold
            })
    
            all_variance.append(explained_variance)
    
            plt.bar(
            range(1,3),
            pca_0.explained_variance_ratio_,
            )
            plt.title(f'explained variance ratio for fold {fold}')
            plt.xlabel("PC")
            plt.ylabel("Explained variance")
            plt.show()
            plot(pca_0_df, proj=proj,epoch=0)
            plot(pca_99_df, proj=proj,epoch=99)

            plot_2(pca_0_df, proj=proj,epoch=0)
            plot_2(pca_99_df,proj=proj,epoch=99)

        
    all_pc_distances = pd.concat(
    all_pc_distances,
    ignore_index=True
     )
    all_pc_separations = pd.concat(all_pc_separations,ignore_index=True)
    all_variance = pd.concat(all_variance,ignore_index=True)
    
    pc_all_folds_df = pd.concat(
    pc_all_folds.values(),
    ignore_index=True
    )
    print(pc_all_folds_df)
    
    return pc_all_folds_df, all_pc_distances, all_pc_separations, all_variance

# %%
def visualize_embeddings_1(proj=False, trained = True):


    all_tissue_embeddings = {}
    all_plasma_embeddings = {}
    all_fold_labels = {}

    for fold in range(5):

        if proj:
            emb = torch.load(
                f"embeddings_orth_recon_task/fold_{fold}_embeddings_proj.pt"
            )
            best_emb = torch.load(
                f"embeddings_orth_recon_task/fold_{fold}_best_embeddings_proj.pt"
            )

            if trained:
                tissue_emb = best_emb["tissue"]["shared"]
                plasma_emb = best_emb["plasma"]["shared"]
            else:
                tissue_emb = emb["epoch0"]["tissue"]["shared"]
                plasma_emb = emb["epoch0"]["plasma"]["shared"]
            print(
            f"Fold {fold}:",
            sorted(tissue_emb.keys())
            )

        else:
            emb = torch.load(
                f"embeddings_orth_loss/fold_{fold}_embeddings.pt"
            )

            if trained:
                tissue_emb = emb["epoch99"]["tissue"]["shared"]
                plasma_emb = emb["epoch99"]["plasma"]["shared"]
            else:
                tissue_emb = emb["epoch0"]["tissue"]["shared"]
                plasma_emb = emb["epoch0"]["plasma"]["shared"]

        # Add embeddings to global dictionaries
        for patient in tissue_emb.keys():
            all_tissue_embeddings[patient] = tissue_emb[patient]
            all_plasma_embeddings[patient] = plasma_emb[patient]
            all_fold_labels[patient] = fold

    combined_pca, combined_pca_df = compute_PCA(
    all_plasma_embeddings,
    all_tissue_embeddings
    )
    combined_pca_df["fold"] = combined_pca_df["patient"].map(all_fold_labels)
    print(combined_pca_df["fold"].unique())
    print(combined_pca_df[["patient", "fold"]].drop_duplicates().sort_values("patient"))


    from sklearn.metrics import roc_auc_score


    for pc in ["PC1", "PC2"]:

        values = combined_pca_df[pc].values

        labels = (
            combined_pca_df["modality"] == "Plasma"
        ).astype(int)

        auc = roc_auc_score(labels, values)

        print(pc, auc)


    distance = paired_distances_per_pc(combined_pca_df)
    distance["fold"] = fold
    print(f'Distances Fold {fold}')
    print(distance)



    separation = modality_separation(combined_pca_df)
    separation["fold"] = fold

    print(f"Fold {fold} separation")
    print(separation)


    explained_variance = pd.DataFrame({
    "PC": [f"PC{i+1}" for i in range(len(combined_pca.explained_variance_ratio_))],
    "explained_variance": combined_pca.explained_variance_ratio_,
    "fold": fold
    })



    plt.bar(
    range(1,3),
    combined_pca.explained_variance_ratio_,
    )
    plt.title(f'explained variance ratio for fold {fold}')
    plt.xlabel("PC")
    plt.ylabel("Explained variance")
    plt.show()
    plot(combined_pca_df,  proj=proj,epoch=100)

    plot_2(combined_pca_df, proj=proj,epoch=100)
    plot_3(combined_pca_df, proj=proj,epoch=100)




    return combined_pca_df, distance, separation, explained_variance

# %%
pc, all_distances, all_separations, all_variance = visualize_embeddings(proj=True, trained=True)
# Out:
# best emb saved at epoch epoch85
# PC1 0.49586776859504134
# PC2 0.3471074380165289
# Distances Fold 0
#     PC  mean_distance  std_distance  fold
# 0  PC1       0.028523      0.033199     0
# 1  PC2       0.036378      0.025928     0
# Fold 0 separation
#     PC  modality_separation  tissue_mean  plasma_mean  fold
# 0  PC1             0.018025     0.009012    -0.009012     0
# 1  PC2             0.030287     0.015143    -0.015143     0
# /home/bmep/plalfken/tmp/ipykernel_1380646/3004291237.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
#  Patient Sample 29 has label symptomatic
#  Patient Sample 88 has label symptomatic
# /home/bmep/plalfken/tmp/ipykernel_1380646/3004291237.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
#  Patient Sample 29 has label symptomatic
#  Patient Sample 88 has label symptomatic
# /home/bmep/plalfken/tmp/ipykernel_1380646/2269939394.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/2269939394.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   size_colors = cm.get_cmap("tab10", 6)
# /home/bmep/plalfken/tmp/ipykernel_1380646/2269939394.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/2269939394.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   size_colors = cm.get_cmap("tab10", 6)
# best emb saved at epoch epoch90
# PC1 0.44628099173553715
# PC2 0.4132231404958678
# Distances Fold 1
#     PC  mean_distance  std_distance  fold
# 0  PC1       0.043163      0.017136     1
# 1  PC2       0.080889      0.055751     1
# Fold 1 separation
#     PC  modality_separation  tissue_mean  plasma_mean  fold
# 0  PC1             0.013988     0.006994    -0.006994     1
# 1  PC2             0.056151     0.028075    -0.028075     1
# /home/bmep/plalfken/tmp/ipykernel_1380646/3004291237.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/3004291237.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/2269939394.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/2269939394.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   size_colors = cm.get_cmap("tab10", 6)
# /home/bmep/plalfken/tmp/ipykernel_1380646/2269939394.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/2269939394.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   size_colors = cm.get_cmap("tab10", 6)
# best emb saved at epoch epoch64
# PC1 0.6199999999999999
# PC2 0.7100000000000001
# Distances Fold 2
#     PC  mean_distance  std_distance  fold
# 0  PC1       0.034757      0.013644     2
# 1  PC2       0.045269      0.026646     2
# Fold 2 separation
#     PC  modality_separation  tissue_mean  plasma_mean  fold
# 0  PC1             0.008863    -0.004431     0.004431     2
# 1  PC2             0.041988    -0.020994     0.020994     2
# /home/bmep/plalfken/tmp/ipykernel_1380646/3004291237.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
#  Patient Sample 1has rupture label!
# /home/bmep/plalfken/tmp/ipykernel_1380646/3004291237.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
#  Patient Sample 1has rupture label!
# /home/bmep/plalfken/tmp/ipykernel_1380646/2269939394.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/2269939394.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   size_colors = cm.get_cmap("tab10", 6)
# /home/bmep/plalfken/tmp/ipykernel_1380646/2269939394.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/2269939394.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   size_colors = cm.get_cmap("tab10", 6)
# best emb saved at epoch epoch79
# PC1 0.52
# PC2 0.6200000000000001
# Distances Fold 3
#     PC  mean_distance  std_distance  fold
# 0  PC1       0.053480      0.046424     3
# 1  PC2       0.038437      0.016764     3
# Fold 3 separation
#     PC  modality_separation  tissue_mean  plasma_mean  fold
# 0  PC1             0.031073     0.015537    -0.015537     3
# 1  PC2             0.025741    -0.012870     0.012870     3
# /home/bmep/plalfken/tmp/ipykernel_1380646/3004291237.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
#  Patient Sample 57 has label symptomatic
#  Patient Sample 66 has label symptomatic
# /home/bmep/plalfken/tmp/ipykernel_1380646/3004291237.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
#  Patient Sample 57 has label symptomatic
#  Patient Sample 66 has label symptomatic
# /home/bmep/plalfken/tmp/ipykernel_1380646/2269939394.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/2269939394.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   size_colors = cm.get_cmap("tab10", 6)
# /home/bmep/plalfken/tmp/ipykernel_1380646/2269939394.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/2269939394.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   size_colors = cm.get_cmap("tab10", 6)
# best emb saved at epoch epoch55
# PC1 0.5599999999999999
# PC2 0.4
# Distances Fold 4
#     PC  mean_distance  std_distance  fold
# 0  PC1       0.107325      0.044715     4
# 1  PC2       0.051049      0.046556     4
# Fold 4 separation
#     PC  modality_separation  tissue_mean  plasma_mean  fold
# 0  PC1             0.001569    -0.000785     0.000785     4
# 1  PC2             0.028207     0.014103    -0.014103     4
# /home/bmep/plalfken/tmp/ipykernel_1380646/3004291237.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/3004291237.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/2269939394.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/2269939394.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   size_colors = cm.get_cmap("tab10", 6)
# /home/bmep/plalfken/tmp/ipykernel_1380646/2269939394.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/2269939394.py:13: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   size_colors = cm.get_cmap("tab10", 6)
#        patient modality       PC1       PC2  fold
# 0    Sample 15   Tissue -0.014057 -0.029858     0
# 1    Sample 15   Plasma -0.049367 -0.079396     0
# 2    Sample 17   Tissue  0.002171 -0.048538     0
# 3    Sample 17   Plasma -0.015176 -0.134514     0
# 4    Sample 28   Tissue  0.066567 -0.019247     0
# ..         ...      ...       ...       ...   ...
# 99   Sample 72   Plasma  0.210292 -0.076377     4
# 100  Sample 77   Tissue  0.124586 -0.050736     4
# 101  Sample 77   Plasma  0.225414 -0.127510     4
# 102  Sample 90   Tissue -0.122475  0.056258     4
# 103  Sample 90   Plasma -0.245569  0.056097     4
#
# [104 rows x 5 columns]

# %%
    combined_pca_df['fold']= foldprint(pc.head())
# Out:
#      patient modality       PC1       PC2  fold
# 0  Sample 15   Tissue -0.115141 -0.084993     0
# 1  Sample 15   Plasma  0.227079 -0.012530     0
# 2  Sample 17   Tissue -0.114333 -0.085744     0
# 3  Sample 17   Plasma  0.236382 -0.045769     0
# 4  Sample 28   Tissue -0.110135 -0.083219     0

# %%
pc_trained, all_distances_trained, all_separations_trained, all_variance_trained = visualize_embeddings(proj=True,
                                                                                                        trained=True)
# Out:
# best emb saved at epoch epoch85
# PC1 0.49586776859504134
# PC2 0.3471074380165289
# Distances Fold 0
#     PC  mean_distance  std_distance  fold
# 0  PC1       0.028523      0.033199     0
# 1  PC2       0.036378      0.025928     0
# Fold 0 separation
#     PC  modality_separation  tissue_mean  plasma_mean  fold
# 0  PC1             0.018025     0.009012    -0.009012     0
# 1  PC2             0.030287     0.015143    -0.015143     0
#  Patient Sample 29 has label symptomatic
#  Patient Sample 88 has label symptomatic
# /home/bmep/plalfken/tmp/ipykernel_1380646/1041986279.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
#  Patient Sample 29 has label symptomatic
#  Patient Sample 88 has label symptomatic
# /home/bmep/plalfken/tmp/ipykernel_1380646/1041986279.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/62171070.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/62171070.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   size_colors = cm.get_cmap("viridis", 6)
# /home/bmep/plalfken/tmp/ipykernel_1380646/62171070.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/62171070.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   size_colors = cm.get_cmap("viridis", 6)
# best emb saved at epoch epoch90
# PC1 0.44628099173553715
# PC2 0.4132231404958678
# Distances Fold 1
#     PC  mean_distance  std_distance  fold
# 0  PC1       0.043163      0.017136     1
# 1  PC2       0.080889      0.055751     1
# Fold 1 separation
#     PC  modality_separation  tissue_mean  plasma_mean  fold
# 0  PC1             0.013988     0.006994    -0.006994     1
# 1  PC2             0.056151     0.028075    -0.028075     1
# /home/bmep/plalfken/tmp/ipykernel_1380646/1041986279.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/1041986279.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/62171070.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/62171070.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   size_colors = cm.get_cmap("viridis", 6)
# /home/bmep/plalfken/tmp/ipykernel_1380646/62171070.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/62171070.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   size_colors = cm.get_cmap("viridis", 6)
# best emb saved at epoch epoch64
# PC1 0.6199999999999999
# PC2 0.7100000000000001
# Distances Fold 2
#     PC  mean_distance  std_distance  fold
# 0  PC1       0.034757      0.013644     2
# 1  PC2       0.045269      0.026646     2
# Fold 2 separation
#     PC  modality_separation  tissue_mean  plasma_mean  fold
# 0  PC1             0.008863    -0.004431     0.004431     2
# 1  PC2             0.041988    -0.020994     0.020994     2
#  Patient Sample 1has rupture label!
# /home/bmep/plalfken/tmp/ipykernel_1380646/1041986279.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
#  Patient Sample 1has rupture label!
# /home/bmep/plalfken/tmp/ipykernel_1380646/1041986279.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/62171070.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/62171070.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   size_colors = cm.get_cmap("viridis", 6)
# /home/bmep/plalfken/tmp/ipykernel_1380646/62171070.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/62171070.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   size_colors = cm.get_cmap("viridis", 6)
# best emb saved at epoch epoch79
# PC1 0.52
# PC2 0.6200000000000001
# Distances Fold 3
#     PC  mean_distance  std_distance  fold
# 0  PC1       0.053480      0.046424     3
# 1  PC2       0.038437      0.016764     3
# Fold 3 separation
#     PC  modality_separation  tissue_mean  plasma_mean  fold
# 0  PC1             0.031073     0.015537    -0.015537     3
# 1  PC2             0.025741    -0.012870     0.012870     3
#  Patient Sample 57 has label symptomatic
#  Patient Sample 66 has label symptomatic
# /home/bmep/plalfken/tmp/ipykernel_1380646/1041986279.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/1041986279.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
#  Patient Sample 57 has label symptomatic
#  Patient Sample 66 has label symptomatic
# /home/bmep/plalfken/tmp/ipykernel_1380646/62171070.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/62171070.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   size_colors = cm.get_cmap("viridis", 6)
# /home/bmep/plalfken/tmp/ipykernel_1380646/62171070.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/62171070.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   size_colors = cm.get_cmap("viridis", 6)
# best emb saved at epoch epoch55
# PC1 0.5599999999999999
# PC2 0.4
# Distances Fold 4
#     PC  mean_distance  std_distance  fold
# 0  PC1       0.107325      0.044715     4
# 1  PC2       0.051049      0.046556     4
# Fold 4 separation
#     PC  modality_separation  tissue_mean  plasma_mean  fold
# 0  PC1             0.001569    -0.000785     0.000785     4
# 1  PC2             0.028207     0.014103    -0.014103     4
# /home/bmep/plalfken/tmp/ipykernel_1380646/1041986279.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/1041986279.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/62171070.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/62171070.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   size_colors = cm.get_cmap("viridis", 6)
# /home/bmep/plalfken/tmp/ipykernel_1380646/62171070.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = cm.get_cmap("tab20", len(patients))
# /home/bmep/plalfken/tmp/ipykernel_1380646/62171070.py:12: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   size_colors = cm.get_cmap("viridis", 6)
#        patient modality       PC1       PC2  fold
# 0    Sample 15   Tissue -0.014057 -0.029858     0
# 1    Sample 15   Plasma -0.049367 -0.079396     0
# 2    Sample 17   Tissue  0.002171 -0.048538     0
# 3    Sample 17   Plasma -0.015176 -0.134514     0
# 4    Sample 28   Tissue  0.066567 -0.019247     0
# ..         ...      ...       ...       ...   ...
# 99   Sample 72   Plasma  0.210292 -0.076377     4
# 100  Sample 77   Tissue  0.124586 -0.050736     4
# 101  Sample 77   Plasma  0.225414 -0.127510     4
# 102  Sample 90   Tissue -0.122475  0.056258     4
# 103  Sample 90   Plasma -0.245569  0.056097     4
#
# [104 rows x 5 columns]

# %%
summary_df = (
    all_distances
    .groupby("PC")
    .agg(
        mean_distance_across_folds=("mean_distance", "mean"),
        std_distance_across_folds=("std_distance", "mean")

    )
    .reset_index()
)

print(summary_df)
# Out:
#     PC  mean_distance_across_folds  std_distance_across_folds
# 0  PC1                    0.214634                   0.172309
# 1  PC2                    0.132111                   0.085913

# %%
summary_df_2 = all_separations.groupby("PC").agg(
        mean_separation_across_folds=("modality_separation", "mean")).reset_index()


print(summary_df_2)
# Out:
#     PC  mean_separation_across_folds
# 0  PC1                      0.179164
# 1  PC2                      0.121732

# %%
print(all_distances)
# Out:
#     PC  mean_distance  std_distance  fold
# 0  PC1       0.204821      0.100052     0
# 1  PC2       0.108232      0.078270     0
# 2  PC1       0.202176      0.114160     1
# 3  PC2       0.246328      0.101552     1
# 4  PC1       0.130522      0.122470     2
# 5  PC2       0.062976      0.054094     2
# 6  PC1       0.240700      0.230900     3
# 7  PC2       0.102052      0.074735     3
# 8  PC1       0.294953      0.293963     4
# 9  PC2       0.140966      0.120917     4

# %%
variance_summary = (
    all_variance
    .groupby("PC")
    .agg(
        mean_variance=("explained_variance", "mean"),
        std_variance=("explained_variance", "std")
    )
    .reset_index()
)

print(variance_summary)
# Out:
#     PC  mean_variance  std_variance
# 0  PC1       0.723396      0.135457
# 1  PC2       0.238144      0.133582

# %%
tissue_scores = pd.read_csv('PR80_30/tissue_pathway_scores.csv')
plasma_scores = pd.read_csv('PR80_30/plasma_pathway_scores.csv')

# %%
tissue_scores.columns
# Out:
# Index(['Name', 'REACTOME_ABC_FAMILY_PROTEINS_MEDIATED_TRANSPORT',
#        'REACTOME_ABC_TRANSPORTER_DISORDERS',
#        'REACTOME_ABORTIVE_ELONGATION_OF_HIV_1_TRANSCRIPT_IN_THE_ABSENCE_OF_TAT',
#        'REACTOME_ACTIVATION_OF_AMPK_DOWNSTREAM_OF_NMDARS',
#        'REACTOME_ACTIVATION_OF_ANTERIOR_HOX_GENES_IN_HINDBRAIN_DEVELOPMENT_DURING_EARLY_EMBRYOGENESIS',
#        'REACTOME_ACTIVATION_OF_APC_C_AND_APC_C_CDC20_MEDIATED_DEGRADATION_OF_MITOTIC_PROTEINS',
#        'REACTOME_ACTIVATION_OF_BH3_ONLY_PROTEINS',
#        'REACTOME_ACTIVATION_OF_GENE_EXPRESSION_BY_SREBF_SREBP',
#        'REACTOME_ACTIVATION_OF_NF_KAPPAB_IN_B_CELLS',
#        ...
#        'REACTOME_UBIQUITIN_DEPENDENT_DEGRADATION_OF_CYCLIN_D',
#        'REACTOME_UBIQUITIN_MEDIATED_DEGRADATION_OF_PHOSPHORYLATED_CDC25A',
#        'REACTOME_UB_SPECIFIC_PROCESSING_PROTEASES', 'REACTOME_UCH_PROTEINASES',
#        'REACTOME_UNFOLDED_PROTEIN_RESPONSE_UPR',
#        'REACTOME_VASOPRESSIN_REGULATES_RENAL_WATER_HOMEOSTASIS_VIA_AQUAPORINS',
#        'REACTOME_VEGFR2_MEDIATED_VASCULAR_PERMEABILITY',
#        'REACTOME_VIF_MEDIATED_DEGRADATION_OF_APOBEC3G',
#        'REACTOME_VIRAL_MESSENGER_RNA_SYNTHESIS',
#        'REACTOME_VISUAL_PHOTOTRANSDUCTION'],
#       dtype='str', length=788)

# %%
tissue_scores.head(10)
# Out:
#         Name  REACTOME_ABC_FAMILY_PROTEINS_MEDIATED_TRANSPORT  \
# 0   Sample 1                                         0.231611
# 1  Sample 11                                         0.249809
# 2  Sample 12                                         0.245607
# 3  Sample 15                                         0.267959
# 4  Sample 16                                         0.080954
# 5  Sample 17                                         0.263611
# 6  Sample 18                                         0.246140
# 7  Sample 20                                         0.220372
# 8  Sample 22                                         0.228273
# 9  Sample 23                                         0.228904
#
#    REACTOME_ABC_TRANSPORTER_DISORDERS  \
# 0                            0.298565
# 1                            0.311428
# 2                            0.298996
# 3                            0.319057
# 4                            0.136135
# 5                            0.326555
# 6                            0.317383
# 7                            0.294001
# 8                            0.295169
# 9                            0.305627
#
#    REACTOME_ABORTIVE_ELONGATION_OF_HIV_1_TRANSCRIPT_IN_THE_ABSENCE_OF_TAT  \
# 0                                          -0.195656
# 1                                          -0.145361
# 2                                          -0.103165
# 3                                          -0.028175
# 4                                          -0.013793
# 5                                          -0.048653
# 6                                          -0.176115
# 7                                          -0.156599
# 8                                          -0.086733
# 9                                          -0.122767
#
#    REACTOME_ACTIVATION_OF_AMPK_DOWNSTREAM_OF_NMDARS  \
# 0                                          0.381296
# 1                                          0.369537
# 2                                          0.386007
# 3                                          0.368957
# 4                                          0.407288
# 5                                          0.386287
# 6                                          0.420972
# 7                                          0.390108
# 8                                          0.346790
# 9                                          0.358950
#
#    REACTOME_ACTIVATION_OF_ANTERIOR_HOX_GENES_IN_HINDBRAIN_DEVELOPMENT_DURING_EARLY_EMBRYOGENESIS  \
# 0                                          -0.024051
# 1                                           0.021594
# 2                                           0.061926
# 3                                           0.111295
# 4                                           0.071336
# 5                                           0.120978
# 6                                           0.065872
# 7                                           0.001871
# 8                                           0.130976
# 9                                           0.000534
#
#    REACTOME_ACTIVATION_OF_APC_C_AND_APC_C_CDC20_MEDIATED_DEGRADATION_OF_MITOTIC_PROTEINS  \
# 0                                           0.236285
# 1                                           0.270736
# 2                                           0.240159
# 3                                           0.268607
# 4                                           0.109390
# 5                                           0.285668
# 6                                           0.281917
# 7                                           0.250885
# 8                                           0.256718
# 9                                           0.269858
#
#    REACTOME_ACTIVATION_OF_BH3_ONLY_PROTEINS  \
# 0                                  0.244072
# 1                                  0.160096
# 2                                  0.170863
# 3                                  0.191422
# 4                                  0.206257
# 5                                  0.187545
# 6                                  0.197777
# 7                                  0.211493
# 8                                  0.204953
# 9                                  0.231695
#
#    REACTOME_ACTIVATION_OF_GENE_EXPRESSION_BY_SREBF_SREBP  \
# 0                                          -0.038372
# 1                                          -0.080457
# 2                                          -0.100291
# 3                                          -0.068818
# 4                                          -0.021286
# 5                                           0.001708
# 6                                           0.097497
# 7                                          -0.122059
# 8                                           0.111702
# 9                                          -0.077087
#
#    REACTOME_ACTIVATION_OF_NF_KAPPAB_IN_B_CELLS  ...  \
# 0                                     0.256376  ...
# 1                                     0.286346  ...
# 2                                     0.257481  ...
# 3                                     0.289242  ...
# 4                                     0.137477  ...
# 5                                     0.313727  ...
# 6                                     0.313148  ...
# 7                                     0.271023  ...
# 8                                     0.283177  ...
# 9                                     0.287472  ...
#
#    REACTOME_UBIQUITIN_DEPENDENT_DEGRADATION_OF_CYCLIN_D  \
# 0                                           0.341682
# 1                                           0.362637
# 2                                           0.333695
# 3                                           0.360411
# 4                                           0.169867
# 5                                           0.373950
# 6                                           0.374153
# 7                                           0.353913
# 8                                           0.339758
# 9                                           0.376997
#
#    REACTOME_UBIQUITIN_MEDIATED_DEGRADATION_OF_PHOSPHORYLATED_CDC25A  \
# 0                                           0.314423
# 1                                           0.342491
# 2                                           0.317007
# 3                                           0.347080
# 4                                           0.155548
# 5                                           0.356760
# 6                                           0.380325
# 7                                           0.330931
# 8                                           0.341139
# 9                                           0.361551
#
#    REACTOME_UB_SPECIFIC_PROCESSING_PROTEASES  REACTOME_UCH_PROTEINASES  \
# 0                                   0.139454                  0.276862
# 1                                   0.155900                  0.300522
# 2                                   0.140801                  0.283895
# 3                                   0.163014                  0.301537
# 4                                   0.060919                  0.176378
# 5                                   0.172577                  0.326875
# 6                                   0.181008                  0.332504
# 7                                   0.149861                  0.280305
# 8                                   0.173733                  0.292657
# 9                                   0.136495                  0.299174
#
#    REACTOME_UNFOLDED_PROTEIN_RESPONSE_UPR  \
# 0                                0.098879
# 1                                0.140011
# 2                                0.145264
# 3                                0.191807
# 4                                0.106016
# 5                                0.172487
# 6                                0.063477
# 7                                0.099326
# 8                                0.113617
# 9                                0.137576
#
#    REACTOME_VASOPRESSIN_REGULATES_RENAL_WATER_HOMEOSTASIS_VIA_AQUAPORINS  \
# 0                                           0.272895
# 1                                           0.227154
# 2                                           0.243143
# 3                                           0.233654
# 4                                           0.066471
# 5                                           0.254060
# 6                                           0.333444
# 7                                           0.209509
# 8                                           0.335077
# 9                                           0.200694
#
#    REACTOME_VEGFR2_MEDIATED_VASCULAR_PERMEABILITY  \
# 0                                        0.037843
# 1                                        0.079617
# 2                                        0.016121
# 3                                        0.026406
# 4                                       -0.035811
# 5                                        0.040117
# 6                                        0.048992
# 7                                        0.064218
# 8                                        0.029222
# 9                                        0.079511
#
#    REACTOME_VIF_MEDIATED_DEGRADATION_OF_APOBEC3G  \
# 0                                       0.342408
# 1                                       0.363096
# 2                                       0.338643
# 3                                       0.371245
# 4                                       0.180530
# 5                                       0.376802
# 6                                       0.386628
# 7                                       0.351140
# 8                                       0.359063
# 9                                       0.373400
#
#    REACTOME_VIRAL_MESSENGER_RNA_SYNTHESIS  REACTOME_VISUAL_PHOTOTRANSDUCTION
# 0                               -0.186140                           0.291460
# 1                               -0.091134                           0.209741
# 2                               -0.047944                           0.204055
# 3                                0.011559                           0.183519
# 4                               -0.109426                           0.237227
# 5                               -0.011550                           0.164714
# 6                               -0.122900                           0.218896
# 7                               -0.149736                           0.229504
# 8                               -0.038249                           0.188179
# 9                               -0.131567                           0.243298
#
# [10 rows x 788 columns]

# %%
plasma_scores.head()
# Out:
#         Name  REACTOME_ABC_FAMILY_PROTEINS_MEDIATED_TRANSPORT  \
# 0   Sample 1                                         0.096858
# 1  Sample 11                                         0.086372
# 2  Sample 12                                         0.123927
# 3  Sample 15                                         0.204250
# 4  Sample 16                                         0.119520
#
#    REACTOME_ABC_TRANSPORTER_DISORDERS  \
# 0                            0.094984
# 1                            0.085952
# 2                            0.126023
# 3                            0.214317
# 4                            0.127293
#
#    REACTOME_ACTIVATION_OF_APC_C_AND_APC_C_CDC20_MEDIATED_DEGRADATION_OF_MITOTIC_PROTEINS  \
# 0                                           0.058428
# 1                                           0.043967
# 2                                           0.126900
# 3                                           0.168489
# 4                                           0.087322
#
#    REACTOME_ACTIVATION_OF_NF_KAPPAB_IN_B_CELLS  \
# 0                                     0.050090
# 1                                     0.043127
# 2                                     0.118129
# 3                                     0.149088
# 4                                     0.074436
#
#    REACTOME_ADAPTIVE_IMMUNE_SYSTEM  REACTOME_ADHERENS_JUNCTIONS_INTERACTIONS  \
# 0                         0.106321                                  0.125298
# 1                         0.179332                                  0.110591
# 2                         0.107311                                  0.141891
# 3                         0.164303                                  0.178233
# 4                         0.175624                                  0.173273
#
#    REACTOME_AEROBIC_RESPIRATION_AND_RESPIRATORY_ELECTRON_TRANSPORT  \
# 0                                          -0.258689
# 1                                           0.177043
# 2                                          -0.203747
# 3                                          -0.138344
# 4                                          -0.032673
#
#    REACTOME_AMPK_INDUCED_ERAD_AND_LYSOSOME_MEDIATED_DEGRADATION_OF_PD_L1_CD274  \
# 0                                           0.063392
# 1                                           0.063402
# 2                                           0.118197
# 3                                           0.180766
# 4                                           0.100792
#
#    REACTOME_AMYLOID_FIBER_FORMATION  ...  \
# 0                          0.328135  ...
# 1                          0.350792  ...
# 2                          0.330911  ...
# 3                          0.293720  ...
# 4                          0.308711  ...
#
#    REACTOME_TRANS_GOLGI_NETWORK_VESICLE_BUDDING  \
# 0                                     -0.065754
# 1                                      0.087497
# 2                                     -0.153949
# 3                                     -0.035744
# 4                                     -0.054808
#
#    REACTOME_UBIQUITIN_DEPENDENT_DEGRADATION_OF_CYCLIN_D  \
# 0                                           0.058428
# 1                                           0.043967
# 2                                           0.126900
# 3                                           0.168489
# 4                                           0.087322
#
#    REACTOME_UBIQUITIN_MEDIATED_DEGRADATION_OF_PHOSPHORYLATED_CDC25A  \
# 0                                           0.033120
# 1                                           0.037454
# 2                                           0.100773
# 3                                           0.138505
# 4                                           0.061651
#
#    REACTOME_UB_SPECIFIC_PROCESSING_PROTEASES  REACTOME_UCH_PROTEINASES  \
# 0                                  -0.034562                  0.069751
# 1                                   0.040187                  0.059640
# 2                                   0.021849                  0.101102
# 3                                   0.100617                  0.159640
# 4                                   0.045543                  0.088421
#
#    REACTOME_UNFOLDED_PROTEIN_RESPONSE_UPR  \
# 0                                0.028000
# 1                                0.127488
# 2                                0.056165
# 3                                0.036210
# 4                                0.047517
#
#    REACTOME_VESICLE_MEDIATED_TRANSPORT  \
# 0                             0.074485
# 1                             0.217874
# 2                             0.047658
# 3                             0.158433
# 4                             0.168302
#
#    REACTOME_VIF_MEDIATED_DEGRADATION_OF_APOBEC3G  \
# 0                                       0.041592
# 1                                       0.041916
# 2                                       0.091935
# 3                                       0.128664
# 4                                       0.054053
#
#    REACTOME_VIRAL_INFECTION_PATHWAYS  REACTOME_VISUAL_PHOTOTRANSDUCTION
# 0                           0.167076                           0.403302
# 1                           0.200743                           0.332635
# 2                           0.142015                           0.385659
# 3                           0.195283                           0.390870
# 4                           0.206920                           0.341060
#
# [5 rows x 318 columns]

# %%
pathways_1 = set(tissue_scores.columns).intersection(plasma_scores.columns) 
#pathways_1.remove('patient')
pathways_1.discard('Name')
print(pathways_1)
# Out:
# {'REACTOME_UNFOLDED_PROTEIN_RESPONSE_UPR', 'REACTOME_CARGO_TRAFFICKING_TO_THE_PERICILIARY_MEMBRANE', 'REACTOME_FCERI_MEDIATED_MAPK_ACTIVATION', 'REACTOME_PROGRAMMED_CELL_DEATH', 'REACTOME_RAB_GEFS_EXCHANGE_GTP_FOR_GDP_ON_RABS', 'REACTOME_INTRINSIC_PATHWAY_OF_FIBRIN_CLOT_FORMATION', 'REACTOME_EPH_EPHRIN_SIGNALING', 'REACTOME_METABOLISM_OF_CARBOHYDRATES_AND_CARBOHYDRATE_DERIVATIVES', 'REACTOME_GLYCOSAMINOGLYCAN_METABOLISM', 'REACTOME_SIGNALING_BY_NOTCH4', 'REACTOME_TRANSCRIPTIONAL_REGULATION_BY_RUNX1', 'REACTOME_TRANS_GOLGI_NETWORK_VESICLE_BUDDING', 'REACTOME_DOWNSTREAM_TCR_SIGNALING', 'REACTOME_INTERFERON_SIGNALING', 'REACTOME_SCF_SKP2_MEDIATED_DEGRADATION_OF_P27_P21', 'REACTOME_APOPTOTIC_CLEAVAGE_OF_CELLULAR_PROTEINS', 'REACTOME_CELL_SURFACE_INTERACTIONS_AT_THE_VASCULAR_WALL', 'REACTOME_SIGNALING_BY_MET', 'REACTOME_TRANSCRIPTIONAL_REGULATION_BY_RUNX2', 'REACTOME_FACTORS_INVOLVED_IN_MEGAKARYOCYTE_DEVELOPMENT_AND_PLATELET_PRODUCTION', 'REACTOME_NUCLEAR_ENVELOPE_NE_REASSEMBLY', 'REACTOME_C_TYPE_LECTIN_RECEPTORS_CLRS', 'REACTOME_INTRA_GOLGI_AND_RETROGRADE_GOLGI_TO_ER_TRAFFIC', 'REACTOME_IMMUNOREGULATORY_INTERACTIONS_BETWEEN_A_LYMPHOID_AND_A_NON_LYMPHOID_CELL', 'REACTOME_HOST_INTERACTIONS_OF_HIV_FACTORS', 'REACTOME_HIGH_LAMINAR_FLOW_SHEAR_STRESS_ACTIVATES_SIGNALING_BY_PIEZO1_AND_PECAM1_CDH5_KDR_IN_ENDOTHELIAL_CELLS', 'REACTOME_SIGNALING_BY_HEDGEHOG', 'REACTOME_DISORDERS_OF_TRANSMEMBRANE_TRANSPORTERS', 'REACTOME_REGULATION_OF_APOPTOSIS', 'REACTOME_PROTEIN_LOCALIZATION', 'REACTOME_COOPERATION_OF_PREFOLDIN_AND_TRIC_CCT_IN_ACTIN_AND_TUBULIN_FOLDING', 'REACTOME_P53_DEPENDENT_G1_DNA_DAMAGE_RESPONSE', 'REACTOME_COMMON_PATHWAY_OF_FIBRIN_CLOT_FORMATION', 'REACTOME_INTERLEUKIN_1_SIGNALING', 'REACTOME_CARGO_RECOGNITION_FOR_CLATHRIN_MEDIATED_ENDOCYTOSIS', 'REACTOME_GOLGI_TO_ER_RETROGRADE_TRANSPORT', 'REACTOME_REGULATION_OF_INSULIN_SECRETION', 'REACTOME_CILIUM_ASSEMBLY', 'REACTOME_ESR_MEDIATED_SIGNALING', 'REACTOME_PLATELET_ACTIVATION_SIGNALING_AND_AGGREGATION', 'REACTOME_ABC_TRANSPORTER_DISORDERS', 'REACTOME_ANTIMICROBIAL_MECHANISM_OF_IFN_STIMULATED_GENES', 'REACTOME_ANTIGEN_PROCESSING_UBIQUITINATION_PROTEASOME_DEGRADATION', 'REACTOME_HEDGEHOG_ON_STATE', 'REACTOME_SEPARATION_OF_SISTER_CHROMATIDS', 'REACTOME_PLASMA_LIPOPROTEIN_ASSEMBLY_REMODELING_AND_CLEARANCE', 'REACTOME_COPI_MEDIATED_ANTEROGRADE_TRANSPORT', 'REACTOME_PLASMA_LIPOPROTEIN_REMODELING', 'REACTOME_AURKA_ACTIVATION_BY_TPX2', 'REACTOME_CELLULAR_RESPONSE_TO_HYPOXIA', 'REACTOME_BIOLOGICAL_OXIDATIONS', 'REACTOME_TRANSLOCATION_OF_SLC2A4_GLUT4_TO_THE_PLASMA_MEMBRANE', 'REACTOME_RAC3_GTPASE_CYCLE', 'REACTOME_ASPARAGINE_N_LINKED_GLYCOSYLATION', 'REACTOME_ACTIVATION_OF_NF_KAPPAB_IN_B_CELLS', 'REACTOME_CYCLIN_A_CDK2_ASSOCIATED_EVENTS_AT_S_PHASE_ENTRY', 'REACTOME_SIGNALING_BY_RECEPTOR_TYROSINE_KINASES', 'REACTOME_MITOTIC_PROMETAPHASE', 'REACTOME_DEUBIQUITINATION', 'REACTOME_REGULATION_OF_CDH1_FUNCTION', 'REACTOME_RIBOSOME_ASSOCIATED_QUALITY_CONTROL', 'REACTOME_TCR_SIGNALING', 'REACTOME_RHOD_GTPASE_CYCLE', 'REACTOME_ROLE_OF_PHOSPHOLIPIDS_IN_PHAGOCYTOSIS', 'REACTOME_SIGNALING_BY_TGF_BETA_RECEPTOR_COMPLEX', 'REACTOME_RAB_GERANYLGERANYLATION', 'REACTOME_CLATHRIN_MEDIATED_ENDOCYTOSIS', 'REACTOME_AMPK_INDUCED_ERAD_AND_LYSOSOME_MEDIATED_DEGRADATION_OF_PD_L1_CD274', 'REACTOME_INFLUENZA_INFECTION', 'REACTOME_SOMITOGENESIS', 'REACTOME_HSP90_CHAPERONE_CYCLE_FOR_STEROID_HORMONE_RECEPTORS_SHR_IN_THE_PRESENCE_OF_LIGAND', 'REACTOME_SIGNALING_BY_INTERLEUKINS', 'REACTOME_FCGAMMA_RECEPTOR_FCGR_DEPENDENT_PHAGOCYTOSIS', 'REACTOME_NCAM_SIGNALING_FOR_NEURITE_OUT_GROWTH', 'REACTOME_CLEC7A_DECTIN_1_SIGNALING', 'REACTOME_DNA_REPLICATION', 'REACTOME_ASYMMETRIC_LOCALIZATION_OF_PCP_PROTEINS', 'REACTOME_GOLGI_ASSOCIATED_VESICLE_BIOGENESIS', 'REACTOME_SIGNALING_BY_TGFB_FAMILY_MEMBERS', 'REACTOME_METABOLISM_OF_AMINO_ACIDS_AND_DERIVATIVES', 'REACTOME_AMYLOID_FIBER_FORMATION', 'REACTOME_NEURONAL_SYSTEM', 'REACTOME_INTRACELLULAR_SIGNALING_BY_SECOND_MESSENGERS', 'REACTOME_UBIQUITIN_MEDIATED_DEGRADATION_OF_PHOSPHORYLATED_CDC25A' ...

# %%
print(pc.head())
# Out:
#      patient modality       PC1       PC2  fold
# 0  Sample 15   Tissue -0.036642 -0.013108     0
# 1  Sample 15   Plasma -0.082302  0.047094     0
# 2  Sample 17   Tissue -0.033297 -0.007281     0
# 3  Sample 17   Plasma -0.096129  0.078334     0
# 4  Sample 28   Tissue  0.005200 -0.006480     0

# %%
tissue_pc = pc[
    pc["modality"] == "Tissue"
]
print(tissue_pc.head())
plasma_pc = pc[pc['modality'] == 'Plasma']
print(plasma_pc.head())
tissue_scores = tissue_scores.rename(columns={"Name": "patient"})
plasma_scores = plasma_scores.rename(columns={"Name": "patient"})

merged_plasma = plasma_pc.merge(
    plasma_scores,
    on="patient",
    how="inner"
)
merged_tissue = tissue_pc.merge(
    tissue_scores,
    on="patient",
    how="inner"
)
# Out:
#      patient modality       PC1       PC2  fold
# 0  Sample 15   Tissue -0.115141 -0.084993     0
# 2  Sample 17   Tissue -0.114333 -0.085744     0
# 4  Sample 28   Tissue -0.110135 -0.083219     0
# 6  Sample 29   Tissue -0.108434 -0.080020     0
# 8  Sample 34   Tissue -0.114442 -0.085942     0
#      patient modality       PC1       PC2  fold
# 1  Sample 15   Plasma  0.227079 -0.012530     0
# 3  Sample 17   Plasma  0.236382 -0.045769     0
# 5  Sample 28   Plasma  0.053430  0.084809     0
# 7  Sample 29   Plasma -0.051759  0.213173     0
# 9  Sample 34   Plasma  0.182947  0.004258     0

# %%
from scipy.stats import pearsonr, spearmanr
merged = tissue_scores.merge(
    plasma_scores,
    on="patient",
    suffixes=("_tissue", "_plasma")
)

results = []

for pathway in pathways_1:

    tissue_col = f"{pathway}_tissue"
    plasma_col = f"{pathway}_plasma"

    # Only keep patients with both scores
    valid = merged[[tissue_col, plasma_col]].dropna()

    if len(valid) < 3:
        continue

    pearson_r, pearson_p = pearsonr(
        valid[tissue_col],
        valid[plasma_col]
    )

    spearman_r, spearman_p = spearmanr(
        valid[tissue_col],
        valid[plasma_col]
    )

    results.append({
        "pathway": pathway,
        "n": len(valid),
        "pearson_r": pearson_r,
        "pearson_p": pearson_p,
        "spearman_r": spearman_r,
        "spearman_p": spearman_p
    })

pathway_correlations = pd.DataFrame(results)

# %%
# Out:
#       patient modality       PC1       PC2  fold  \
# 0   Sample 15   Tissue -0.108386 -0.032394     0
# 1   Sample 17   Tissue -0.110124 -0.033065     0
# 2   Sample 28   Tissue -0.109873 -0.030569     0
# 3   Sample 29   Tissue -0.094850 -0.023718     0
# 4   Sample 34   Tissue -0.110183 -0.032522     0
# 5   Sample 38   Tissue -0.099050 -0.025389     0
# 6   Sample 61   Tissue -0.112108 -0.032271     0
# 7   Sample 76   Tissue -0.091647 -0.022262     0
# 8   Sample 78   Tissue -0.096925 -0.030818     0
# 9   Sample 85   Tissue -0.103912 -0.032086     0
# 10  Sample 88   Tissue -0.089457 -0.021295     0
# 11  Sample 16   Tissue -0.013586 -0.143473     1
# 12  Sample 18   Tissue -0.016005 -0.107147     1
# 13  Sample 22   Tissue -0.016222 -0.112067     1
# 14  Sample 31   Tissue -0.017882 -0.118526     1
# 15  Sample 49   Tissue -0.010346 -0.135856     1
# 16  Sample 51   Tissue -0.018315 -0.124218     1
# 17  Sample 64   Tissue  0.002353 -0.106678     1
# 18  Sample 65   Tissue -0.017405 -0.104200     1
# 19  Sample 70   Tissue -0.013512 -0.142468     1
# 20  Sample 79   Tissue -0.012757 -0.141531     1
# 21  Sample 87   Tissue -0.002847 -0.118641     1
# 22   Sample 1   Tissue -0.066227 -0.033575     2
# 23  Sample 23   Tissue -0.071126 -0.027796     2
# 24  Sample 25   Tissue -0.068780 -0.028954     2
# 25  Sample 32   Tissue -0.055553 -0.033890     2
# 26   Sample 5   Tissue -0.070559 -0.030365     2
# 27  Sample 52   Tissue -0.069099 -0.028454     2
# 28  Sample 59   Tissue -0.051864 -0.035310     2
# 29  Sample 60   Tissue -0.054513 -0.034529     2
# 30   Sample 7   Tissue -0.072980 -0.027137     2
# 31  Sample 83   Tissue -0.071908 -0.028924     2
# 32  Sample 11   Tissue -0.128442 -0.057600     3
# 33  Sample 12   Tissue -0.126201 -0.055819     3
# 34  Sample 42   Tissue -0.104316 -0.037908     3
# 35  Sample 48   Tissue -0.105743 -0.038990     3
# 36  Sample 57   Tissue -0.110207 -0.042720     3
# 37  Sample 66   Tissue -0.125467 -0.055211     3
# 38  Sample 73   Tissue -0.128405 -0.057680     3
# 39  Sample 75   Tissue -0.128195 -0.057523     3
# 40  Sample 82   Tissue -0.117453 -0.048478     3
# 41  Sample 86   Tissue -0.129071 -0.058332     3
# 42  Sample 20   Tissue -0.147015 -0.079192     4
# 43  Sample 24   Tissue -0.134898 -0.038892     4
# 44  Sample 30   Tissue -0.146764 -0.079125     4
# 45  Sample 36   Tissue -0.159054 -0.082657     4
# 46  Sample 39   Tissue -0.147460 -0.059402     4
# 47  Sample 45   Tissue -0.152731 -0.068611     4
# 48  Sample 55   Tissue -0.150376 -0.080140     4
# 49  Sample 72   Tissue -0.145802 -0.078800     4
# 50  Sample 77   Tissue -0.142526 -0.077634     4
# 51  Sample 90   Tissue -0.148140 -0.060378     4
#
#     REACTOME_ABC_FAMILY_PROTEINS_MEDIATED_TRANSPORT  \
# 0                                          0.267959
# 1                                          0.263611
# 2                                          0.224963
# 3                                          0.248190
# 4                                          0.251397
# 5                                          0.242503
# 6                                          0.270275
# 7                                          0.242900
# 8                                          0.233383
# 9                                          0.223417
# 10                                         0.223031
# 11                                         0.080954
# 12                                         0.246140
# 13                                         0.228273
# 14                                         0.260667
# 15                                         0.251045
# 16                                         0.242621
# 17                                         0.223521
# 18                                         0.287592
# 19                                         0.289164
# 20                                         0.243780
# 21                                         0.169183
# 22                                         0.231611
# 23                                         0.228904
# 24                                         0.272803
# 25                                         0.178874
# 26                                         0.154257
# 27                                         0.227965
# 28                                         0.201153
# 29                                         0.247443
# 30                                         0.276872
# 31                                         0.233255
# 32                                         0.249809
# 33                                         0.245607
# 34                                         0.237792
# 35                                         0.309293
# 36                                         0.283720
# 37                                         0.211371
# 38                                         0.218266
# 39                                         0.265427
# 40                                         0.275059
# 41                                         0.238297
# 42                                         0.220372
# 43                                         0.273578
# 44                                         0.287592
# 45                                         0.254886
# 46                                         0.302027
# 47                                         0.230878
# 48                                         0.298609
# 49                                         0.226819
# 50                                         0.204058
# 51                                         0.166007
#
#     REACTOME_ABC_TRANSPORTER_DISORDERS  \
# 0                             0.319057
# 1                             0.326555
# 2                             0.275327
# 3                             0.292653
# 4                             0.323403
# 5                             0.300087
# 6                             0.321046
# 7                             0.294632
# 8                             0.321743
# 9                             0.285743
# 10                            0.298638
# 11                            0.136135
# 12                            0.317383
# 13                            0.295169
# 14                            0.293829
# 15                            0.323475
# 16                            0.297136
# 17                            0.277866
# 18                            0.331934
# 19                            0.350731
# 20                            0.324617
# 21                            0.253875
# 22                            0.298565
# 23                            0.305627
# 24                            0.312808
# 25                            0.252351
# 26                            0.234166
# 27                            0.281648
# 28                            0.274793
# 29                            0.315218
# 30                            0.359589
# 31                            0.301818
# 32                            0.311428
# 33                            0.298996
# 34                            0.302980
# 35                            0.378048
# 36                            0.371161
# 37                            0.268141
# 38                            0.268604
# 39                            0.343950
# 40                            0.331653
# 41                            0.298529
# 42                            0.294001
# 43                            0.336350
# 44                            0.368532
# 45                            0.323520
# 46                            0.375698
# 47                            0.278242
# 48                            0.367425
# 49                            0.267838
# 50                            0.256609
# 51                            0.207327
#
#     REACTOME_ABORTIVE_ELONGATION_OF_HIV_1_TRANSCRIPT_IN_THE_ABSENCE_OF_TAT  \
# 0                                           -0.028175
# 1                                           -0.048653
# 2                                           -0.102063
# 3                                            0.009224
# 4                                           -0.186267
# 5                                           -0.127166
# 6                                           -0.064063
# 7                                           -0.128620
# 8                                           -0.067160
# 9                                           -0.107027
# 10                                          -0.100767
# 11                                          -0.013793
# 12                                          -0.176115
# 13                                          -0.086733
# 14                                           0.019658
# 15                                          -0.064977
# 16                                          -0.102386
# 17                                          -0.194020
# 18                                          -0.096121
# 19                                          -0.045326
# 20                                          -0.042797
# 21                                           0.029751
# 22                                          -0.195656
# 23                                          -0.122767
# 24                                          -0.053336
# 25                                          -0.021199
# 26                                          -0.010488
# 27                                          -0.134763
# 28                                          -0.031155
# 29                                          -0.168395
# 30                                          -0.021666
# 31                                          -0.086336
# 32                                          -0.145361
# 33                                          -0.103165
# 34                                          -0.038172
# 35                                          -0.068441
# 36                                          -0.058126
# 37                                          -0.137543
# 38                                           0.013941
# 39                                          -0.067512
# 40                                          -0.054909
# 41                                          -0.061398
# 42                                          -0.156599
# 43                                          -0.125579
# 44                                          -0.087938
# 45                                          -0.102677
# 46                                          -0.023369
# 47                                          -0.095234
# 48                                          -0.130039
# 49                                          -0.125396
# 50                                          -0.171325
# 51                                          -0.069724
#
#     REACTOME_ACTIVATION_OF_AMPK_DOWNSTREAM_OF_NMDARS  \
# 0                                           0.368957
# 1                                           0.386287
# 2                                           0.439073
# 3                                           0.413837
# 4                                           0.350263
# 5                                           0.431349
# 6                                           0.371132
# 7                                           0.456104
# 8                                           0.319458
# 9                                           0.385716
# 10                                          0.344962
# 11                                          0.407288
# 12                                          0.420972
# 13                                          0.346790
# 14                                          0.421555
# 15                                          0.376710
# 16                                          0.378525
# 17                                          0.413823
# 18                                          0.421526
# 19                                          0.359108
# 20                                          0.380718
# 21                                          0.338582
# 22                                          0.381296
# 23                                          0.358950
# 24                                          0.332175
# 25                                          0.358582
# 26                                          0.348247
# 27                                          0.356485
# 28                                          0.360446
# 29                                          0.390782
# 30                                          0.379058
# 31                                          0.384810
# 32                                          0.369537
# 33                                          0.386007
# 34                                          0.416505
# 35                                          0.380236
# 36                                          0.341740
# 37                                          0.426984
# 38                                          0.223613
# 39                                          0.454520
# 40                                          0.405709
# 41                                          0.410991
# 42                                          0.390108
# 43                                          0.381413
# 44                                          0.371183
# 45                                          0.344338
# 46                                          0.365927
# 47                                          0.380131
# 48                                          0.384444
# 49                                          0.457180
# 50                                          0.429565
# 51                                          0.450866
#
#     REACTOME_ACTIVATION_OF_ANTERIOR_HOX_GENES_IN_HINDBRAIN_DEVELOPMENT_DURING_EARLY_EMBRYOGENESIS  \
# 0                                            0.111295
# 1                                            0.120978
# 2                                            0.092123
# 3                                            0.118587
# 4                                            0.022079
# 5                                            0.073249
# 6                                            0.044891
# 7                                            0.068837
# 8                                           -0.012014
# 9                                            0.027708
# 10                                           0.044252
# 11                                           0.071336
# 12                                           0.065872
# 13                                           0.130976
# 14                                           0.154248
# 15                                           0.081565
# 16                                           0.032409
# 17                                          -0.071846
# 18                                           0.105062
# 19                                           0.111930
# 20                                          -0.026809
# 21                                           0.100126
# 22                                          -0.024051
# 23                                           0.000534
# 24                                           0.124611
# 25                                           0.079749
# 26                                           0.062468
# 27                                           0.007047
# 28                                           0.001162
# 29                                           0.055920
# 30                                           0.090815
# 31                                           0.032485
# 32                                           0.021594
# 33                                           0.061926
# 34                                           0.085281
# 35                                           0.079527
# 36                                           0.081350
# 37                                           0.031820
# 38                                           0.169547
# 39                                           0.070693
# 40                                           0.101274
# 41                                           0.122202
# 42                                           0.001871
# 43                                           0.022933
# 44                                           0.072219
# 45                                           0.060459
# 46                                           0.081680
# 47                                           0.075296
# 48                                           0.060846
# 49                                           0.097417
# 50                                           0.005570
# 51                                           0.070171
#
#     ...  REACTOME_UBIQUITIN_DEPENDENT_DEGRADATION_OF_CYCLIN_D  \
# 0   ...                                           0.360411
# 1   ...                                           0.373950
# 2   ...                                           0.334280
# 3   ...                                           0.351377
# 4   ...                                           0.355574
# 5   ...                                           0.320875
# 6   ...                                           0.371834
# 7   ...                                           0.335243
# 8   ...                                           0.355699
# 9   ...                                           0.337816
# 10  ...                                           0.357952
# 11  ...                                           0.169867
# 12  ...                                           0.374153
# 13  ...                                           0.339758
# 14  ...                                           0.322583
# 15  ...                                           0.391723
# 16  ...                                           0.330425
# 17  ...                                           0.347524
# 18  ...                                           0.373947
# 19  ...                                           0.394300
# 20  ...                                           0.395051
# 21  ...                                           0.309009
# 22  ...                                           0.341682
# 23  ...                                           0.376997
# 24  ...                                           0.329179
# 25  ...                                           0.320342
# 26  ...                                           0.307165
# 27  ...                                           0.329511
# 28  ...                                           0.343141
# 29  ...                                           0.348091
# 30  ...                                           0.411817
# 31  ...                                           0.351864
# 32  ...                                           0.362637
# 33  ...                                           0.333695
# 34  ...                                           0.350435
# 35  ...                                           0.414219
# 36  ...                                           0.412792
# 37  ...                                           0.343384
# 38  ...                                           0.308812
# 39  ...                                           0.400011
# 40  ...                                           0.380593
# 41  ...                                           0.319909
# 42  ...                                           0.353913
# 43  ...                                           0.369739
# 44  ...                                           0.431035
# 45  ...                                           0.328748
# 46  ...                                           0.441521
# 47  ...                                           0.301516
# 48  ...                                           0.428200
# 49  ...                                           0.298329
# 50  ...                                           0.314412
# 51  ...                                           0.245793
#
#     REACTOME_UBIQUITIN_MEDIATED_DEGRADATION_OF_PHOSPHORYLATED_CDC25A  \
# 0                                            0.347080
# 1                                            0.356760
# 2                                            0.324678
# 3                                            0.326804
# 4                                            0.327221
# 5                                            0.304060
# 6                                            0.350296
# 7                                            0.327260
# 8                                            0.328962
# 9                                            0.334932
# 10                                           0.341114
# 11                                           0.155548
# 12                                           0.380325
# 13                                           0.341139
# 14                                           0.295417
# 15                                           0.386561
# 16                                           0.298544
# 17                                           0.315218
# 18                                           0.360610
# 19                                           0.387759
# 20                                           0.381413
# 21                                           0.295085
# 22                                           0.314423
# 23                                           0.361551
# 24                                           0.310906
# 25                                           0.294979
# 26                                           0.277230
# 27                                           0.296116
# 28                                           0.311524
# 29                                           0.346855
# 30                                           0.416537
# 31                                           0.337628
# 32                                           0.342491
# 33                                           0.317007
# 34                                           0.332904
# 35                                           0.401104
# 36                                           0.407491
# 37                                           0.316019
# 38                                           0.302630
# 39                                           0.398825
# 40                                           0.374923
# 41                                           0.297552
# 42                                           0.330931
# 43                                           0.368171
# 44                                           0.428028
# 45                                           0.296983
# 46                                           0.441131
# 47                                           0.289602
# 48                                           0.400786
# 49                                           0.270335
# 50                                           0.294223
# 51                                           0.223666
#
#     REACTOME_UB_SPECIFIC_PROCESSING_PROTEASES  REACTOME_UCH_PROTEINASES  \
# 0                                    0.163014                  0.301537
# 1                                    0.172577                  0.326875
# 2                                    0.172835                  0.274106
# 3                                    0.151514                  0.291713
# 4                                    0.146227                  0.302165
# 5                                    0.142928                  0.270575
# 6                                    0.181486                  0.307077
# 7                                    0.163800                  0.281550
# 8                                    0.151350                  0.294463
# 9                                    0.158722                  0.293317
# 10                                   0.127590                  0.284493
# 11                                   0.060919                  0.176378
# 12                                   0.181008                  0.332504
# 13                                   0.173733                  0.292657
# 14                                   0.134257                  0.277518
# 15                                   0.201981                  0.339135
# 16                                   0.119559                  0.274975
# 17                                   0.141236                  0.267014
# 18                                   0.184063                  0.320611
# 19                                   0.195438                  0.332457
# 20                                   0.169609                  0.343728
# 21                                   0.141906                  0.266277
# 22                                   0.139454                  0.276862
# 23                                   0.136495                  0.299174
# 24                                   0.140930                  0.273481
# 25                                   0.112536                  0.275431
# 26                                   0.129399                  0.278164
# 27                                   0.137653                  0.264147
# 28                                   0.111296                  0.274124
# 29                                   0.168552                  0.293791
# 30                                   0.209276                  0.354044
# 31                                   0.153984                  0.276395
# 32                                   0.155900                  0.300522
# 33                                   0.140801                  0.283895
# 34                                   0.158639                  0.303416
# 35                                   0.214484                  0.358867
# 36                                   0.194537                  0.350260
# 37                                   0.164811                  0.285641
# 38                                   0.141128                  0.271389
# 39                                   0.189826                  0.334599
# 40                                   0.163281                  0.301421
# 41                                   0.131831                  0.275805
# 42                                   0.149861                  0.280305
# 43                                   0.169115                  0.312208
# 44                                   0.217746                  0.368703
# 45                                   0.135933                  0.272982
# 46                                   0.225114                  0.376246
# 47                                   0.115636                  0.261118
# 48                                   0.222490                  0.357997
# 49                                   0.136018                  0.254545
# 50                                   0.157272                  0.256425
# 51                                   0.090406                  0.207746
#
#     REACTOME_UNFOLDED_PROTEIN_RESPONSE_UPR  \
# 0                                 0.191807
# 1                                 0.172487
# 2                                 0.150943
# 3                                 0.254190
# 4                                 0.124475
# 5                                 0.150086
# 6                                 0.189749
# 7                                 0.178491
# 8                                 0.143100
# 9                                 0.133664
# 10                                0.145425
# 11                                0.106016
# 12                                0.063477
# 13                                0.113617
# 14                                0.246615
# 15                                0.130928
# 16                                0.098400
# 17                                0.112279
# 18                                0.142029
# 19                                0.191482
# 20                                0.124732
# 21                                0.081535
# 22                                0.098879
# 23                                0.137576
# 24                                0.232786
# 25                                0.090699
# 26                                0.069684
# 27                                0.141227
# 28                                0.095585
# 29                                0.105012
# 30                                0.112250
# 31                                0.140157
# 32                                0.140011
# 33                                0.145264
# 34                                0.185570
# 35                                0.143582
# 36                                0.162746
# 37                                0.129354
# 38                                0.219205
# 39                                0.069454
# 40                                0.112710
# 41                                0.205410
# 42                                0.099326
# 43                                0.134015
# 44                                0.077327
# 45                                0.221586
# 46                                0.112294
# 47                                0.165097
# 48                                0.094171
# 49                                0.148492
# 50                                0.109788
# 51                                0.146602
#
#     REACTOME_VASOPRESSIN_REGULATES_RENAL_WATER_HOMEOSTASIS_VIA_AQUAPORINS  \
# 0                                            0.233654
# 1                                            0.254060
# 2                                            0.326271
# 3                                            0.175283
# 4                                            0.254131
# 5                                            0.276379
# 6                                            0.227953
# 7                                            0.298559
# 8                                            0.110443
# 9                                            0.182156
# 10                                           0.195461
# 11                                           0.066471
# 12                                           0.333444
# 13                                           0.335077
# 14                                           0.223574
# 15                                           0.174105
# 16                                           0.185078
# 17                                           0.252153
# 18                                           0.349447
# 19                                           0.278793
# 20                                           0.092558
# 21                                           0.092038
# 22                                           0.272895
# 23                                           0.200694
# 24                                           0.212961
# 25                                           0.146597
# 26                                          -0.051241
# 27                                           0.236625
# 28                                           0.209893
# 29                                           0.340753
# 30                                           0.279522
# 31                                           0.162639
# 32                                           0.227154
# 33                                           0.243143
# 34                                           0.245199
# 35                                           0.278677
# 36                                           0.278236
# 37                                           0.301589
# 38                                           0.209171
# 39                                           0.233692
# 40                                           0.280991
# 41                                           0.287314
# 42                                           0.209509
# 43                                           0.198908
# 44                                           0.221264
# 45                                           0.218579
# 46                                           0.269923
# 47                                           0.245759
# 48                                           0.318857
# 49                                           0.351177
# 50                                           0.291209
# 51                                           0.274863
#
#     REACTOME_VEGFR2_MEDIATED_VASCULAR_PERMEABILITY  \
# 0                                         0.026406
# 1                                         0.040117
# 2                                         0.039588
# 3                                         0.031089
# 4                                         0.007186
# 5                                         0.022342
# 6                                         0.056040
# 7                                         0.088070
# 8                                         0.023993
# 9                                        -0.004614
# 10                                        0.063840
# 11                                       -0.035811
# 12                                        0.048992
# 13                                        0.029222
# 14                                        0.019807
# 15                                        0.124394
# 16                                        0.038987
# 17                                        0.044453
# 18                                        0.072609
# 19                                        0.062791
# 20                                        0.005420
# 21                                        0.056715
# 22                                        0.037843
# 23                                        0.079511
# 24                                        0.025837
# 25                                        0.059482
# 26                                        0.047646
# 27                                        0.018358
# 28                                        0.092472
# 29                                        0.053968
# 30                                        0.074294
# 31                                        0.031129
# 32                                        0.079617
# 33                                        0.016121
# 34                                        0.041801
# 35                                        0.044903
# 36                                        0.035708
# 37                                        0.071888
# 38                                       -0.015627
# 39                                        0.062803
# 40                                        0.093282
# 41                                        0.032256
# 42                                        0.064218
# 43                                        0.019966
# 44                                        0.050896
# 45                                       -0.011670
# 46                                        0.073791
# 47                                       -0.009920
# 48                                        0.019658
# 49                                        0.080253
# 50                                        0.056333
# 51                                        0.014129
#
#     REACTOME_VIF_MEDIATED_DEGRADATION_OF_APOBEC3G  \
# 0                                        0.371245
# 1                                        0.376802
# 2                                        0.336420
# 3                                        0.356206
# 4                                        0.357194
# 5                                        0.325857
# 6                                        0.376182
# 7                                        0.339903
# 8                                        0.350182
# 9                                        0.355794
# 10                                       0.349487
# 11                                       0.180530
# 12                                       0.386628
# 13                                       0.359063
# 14                                       0.326778
# 15                                       0.392566
# 16                                       0.331712
# 17                                       0.339356
# 18                                       0.381386
# 19                                       0.400565
# 20                                       0.398620
# 21                                       0.298465
# 22                                       0.342408
# 23                                       0.373400
# 24                                       0.340083
# 25                                       0.323329
# 26                                       0.305326
# 27                                       0.326922
# 28                                       0.349373
# 29                                       0.361175
# 30                                       0.422856
# 31                                       0.356466
# 32                                       0.363096
# 33                                       0.338643
# 34                                       0.350333
# 35                                       0.419481
# 36                                       0.419497
# 37                                       0.340133
# 38                                       0.336230
# 39                                       0.408351
# 40                                       0.386925
# 41                                       0.327021
# 42                                       0.351140
# 43                                       0.373514
# 44                                       0.439067
# 45                                       0.329382
# 46                                       0.443431
# 47                                       0.308560
# 48                                       0.421588
# 49                                       0.297490
# 50                                       0.314996
# 51                                       0.239236
#
#     REACTOME_VIRAL_MESSENGER_RNA_SYNTHESIS  REACTOME_VISUAL_PHOTOTRANSDUCTION
# 0                                 0.011559                           0.183519
# 1                                -0.011550                           0.164714
# 2                                -0.060189                           0.192436
# 3                                 0.068401                           0.135904
# 4                                -0.157101                           0.248650
# 5                                -0.078938                           0.254468
# 6                                -0.029961                           0.128920
# 7                                -0.080854                           0.219405
# 8                                -0.137917                           0.194255
# 9                                -0.121157                           0.161794
# 10                               -0.108783                           0.252759
# 11                               -0.109426                           0.237227
# 12                               -0.122900                           0.218896
# 13                               -0.038249                           0.188179
# 14                                0.109674                           0.198941
# 15                               -0.047926                           0.173961
# 16                               -0.028301                           0.250679
# 17                               -0.191514                           0.302707
# 18                               -0.012547                           0.274750
# 19                               -0.000771                           0.164845
# 20                               -0.147000                           0.228793
# 21                               -0.088374                           0.161220
# 22                               -0.186140                           0.291460
# 23                               -0.131567                           0.243298
# 24                                0.075352                           0.078470
# 25                               -0.163397                           0.220833
# 26                               -0.101616                           0.188031
# 27                               -0.102625                           0.198733
# 28                               -0.091991                           0.259967
# 29                               -0.101622                           0.200858
# 30                               -0.066757                           0.201887
# 31                               -0.036193                           0.193882
# 32                               -0.091134                           0.209741
# 33                               -0.047944                           0.204055
# 34                               -0.026598                           0.189910
# 35                               -0.047213                           0.264158
# 36                               -0.038787                           0.150912
# 37                               -0.141600                           0.212986
# 38                                0.049702                           0.177374
# 39                               -0.163674                           0.230065
# 40                               -0.073641                           0.228089
# 41                               -0.004583                           0.219029
# 42                               -0.149736                           0.229504
# 43                               -0.079524                           0.174025
# 44                               -0.161873                           0.239792
# 45                               -0.030033                           0.192911
# 46                               -0.096351                           0.187189
# 47                                0.000235                           0.209481
# 48                               -0.096653                           0.235843
# 49                               -0.045592                           0.191488
# 50                               -0.098799                           0.289704
# 51                               -0.052054                           0.207389
#
# [52 rows x 792 columns]

# %%
pc_trained = pc_trained.rename(
    columns={
        col: f"trained_{col}"
        for col in pc_trained.columns
        if col.startswith("PC")
    }
)
pc = pc.merge(
    pc_trained,
    on=["patient", "modality","fold"],
    how="left"
)

# %%
tissue_pc = pc[
    pc["modality"] == "Tissue"
]
print(tissue_pc.head())
plasma_pc = pc[pc['modality'] == 'Plasma']
print(plasma_pc.head())
tissue_scores = tissue_scores.rename(columns={"Name": "patient"})
plasma_scores = plasma_scores.rename(columns={"Name": "patient"})

merged_plasma = plasma_pc.merge(
    plasma_scores,
    on="patient",
    how="inner"
)
merged_tissue = tissue_pc.merge(
    tissue_scores,
    on="patient",
    how="inner"
)
# Out:
#      patient modality       PC1       PC2  fold  trained_PC1  trained_PC2
# 0  Sample 15   Tissue -0.115141 -0.084993     0    -0.014057    -0.029858
# 2  Sample 17   Tissue -0.114333 -0.085744     0     0.002171    -0.048538
# 4  Sample 28   Tissue -0.110135 -0.083219     0     0.066567    -0.019247
# 6  Sample 29   Tissue -0.108434 -0.080020     0     0.059889     0.064443
# 8  Sample 34   Tissue -0.114442 -0.085942     0     0.009040    -0.033229
#      patient modality       PC1       PC2  fold  trained_PC1  trained_PC2
# 1  Sample 15   Plasma  0.227079 -0.012530     0    -0.049367    -0.079396
# 3  Sample 17   Plasma  0.236382 -0.045769     0    -0.015176    -0.134514
# 5  Sample 28   Plasma  0.053430  0.084809     0     0.085473    -0.074756
# 7  Sample 29   Plasma -0.051759  0.213173     0     0.057587     0.061742
# 9  Sample 34   Plasma  0.182947  0.004258     0    -0.004265    -0.084316

# %%
from scipy.stats import pearsonr, spearmanr


def correlate_pc_pathways(df, pc_cols=("PC1", "PC2","trained_PC1","trained_PC2")):
    results = []

    # pathway columns = everything except metadata + PCs
    metadata = {"patient", "modality", "fold", "Name"}
    pathway_cols = [
        col for col in df.columns
        if col not in metadata and col not in pc_cols
    ]

    for pc in pc_cols:
        for pathway in pathway_cols:

            # Remove missing values for this particular pair
            valid = df[[pc, pathway]].dropna()

            if len(valid) < 3:
                continue

            pearson_r, pearson_p = pearsonr(
                valid[pc],
                valid[pathway]
            )

            spearman_r, spearman_p = spearmanr(
                valid[pc],
                valid[pathway]
            )

            results.append({
                "PC": pc,
                "pathway": pathway,
                "n": len(valid),
                "pearson_r": pearson_r,
                "pearson_p": pearson_p,
                "spearman_r": spearman_r,
                "spearman_p": spearman_p
            })

    return pd.DataFrame(results)

# %%
from statsmodels.stats.multitest import multipletests

def add_fdr(results):

    results = results.copy()

    results["pearson_fdr"] = multipletests(
        results["pearson_p"],
        method="fdr_bh"
    )[1]

    results["spearman_fdr"] = multipletests(
        results["spearman_p"],
        method="fdr_bh"
    )[1]

    return results

# %%
tissue_results = []

for fold in range(5):

    fold_df = merged_tissue[
        merged_tissue["fold"] == fold
    ]

    result = correlate_pc_pathways(fold_df)
    result["fold"] = fold

    tissue_results.append(result)

tissue_results = pd.concat(
    tissue_results,
    ignore_index=True
)

tissue_results.sort_values(
    "pearson_r",
    ascending=False
).head(20)
# Out:
#                 PC                                            pathway   n  \
# 14770  trained_PC1                         REACTOME_RND2_GTPASE_CYCLE  10
# 1997   trained_PC1                REACTOME_NERVOUS_SYSTEM_DEVELOPMENT  11
# 14771  trained_PC1                         REACTOME_RND3_GTPASE_CYCLE  10
# 13946          PC2                             REACTOME_RET_SIGNALING  10
# 7437           PC2                      REACTOME_LEISHMANIA_INFECTION  10
# 8224   trained_PC1                      REACTOME_LEISHMANIA_INFECTION  10
# 2209   trained_PC1  REACTOME_SENESCENCE_ASSOCIATED_SECRETORY_PHENO...  11
# 1618   trained_PC1                         REACTOME_ATTENUATION_PHASE  11
# 1712   trained_PC1  REACTOME_DEFECTIVE_INTRINSIC_PATHWAY_FOR_APOPT...  11
# 2095   trained_PC1     REACTOME_REGULATION_OF_CDH1_GENE_TRANSCRIPTION  11
# 14753  trained_PC1                 REACTOME_RHO_GTPASES_ACTIVATE_PKNS  10
# 14403  trained_PC1  REACTOME_FORMATION_OF_THE_DYSTROPHIN_GLYCOPROT...  10
# 5097   trained_PC1                    REACTOME_METABOLISM_OF_STEROIDS  11
# 1398           PC2                     REACTOME_RSV_HOST_INTERACTIONS  11
# 14707  trained_PC1  REACTOME_REGULATION_OF_PLK1_ACTIVITY_AT_G2_M_T...  10
# 3523           PC1                    REACTOME_METABOLISM_OF_STEROIDS  11
# 2149   trained_PC1                         REACTOME_RHOF_GTPASE_CYCLE  11
# 13426          PC2                                 REACTOME_AUTOPHAGY  10
# 12722          PC1                        REACTOME_DAP12_INTERACTIONS  10
# 1873   trained_PC1            REACTOME_HSF1_DEPENDENT_TRANSACTIVATION  11
#
#        pearson_r  pearson_p  spearman_r  spearman_p  fold
# 14770   0.960351   0.000010    0.939394    0.000055     4
# 1997    0.894711   0.000200    0.800000    0.003110     0
# 14771   0.871320   0.001024    0.781818    0.007547     4
# 13946   0.862604   0.001316    0.866667    0.001174     4
# 7437    0.856628   0.001549    0.745455    0.013330     2
# 8224    0.855848   0.001582    0.903030    0.000344     2
# 2209    0.853744   0.000826    0.490909    0.125204     0
# 1618    0.850541   0.000906    0.763636    0.006233     0
# 1712    0.842564   0.001131    0.545455    0.082651     0
# 2095    0.842187   0.001143    0.536364    0.088953     0
# 14753   0.835718   0.002600    0.757576    0.011143     4
# 14403   0.827724   0.003113    0.866667    0.001174     4
# 5097    0.822972   0.001861    0.736364    0.009760     1
# 1398    0.822889   0.001865    0.809091    0.002559     0
# 14707   0.821309   0.003573    0.818182    0.003815     4
# 3523    0.817629   0.002110    0.727273    0.011205     1
# 2149    0.815722   0.002205    0.654545    0.028865     0
# 13426   0.815352   0.004043    0.757576    0.011143     4
# 12722   0.806687   0.004803    0.830303    0.002940     4
# 1873    0.805872   0.002745    0.790909    0.003746     0

# %%
plasma_results = []

for fold in range(5):

    fold_df = merged_plasma[
        merged_plasma["fold"] == fold
    ]

    result = correlate_pc_pathways(fold_df)
    result["fold"] = fold

    plasma_results.append(result)

plasma_results = pd.concat(
    plasma_results,
    ignore_index=True
)
plasma_results.sort_values(
    "pearson_r",
    ascending=False
).head(20)
# Out:
#                PC                                            pathway   n  \
# 1599          PC2  REACTOME_ANTIMICROBIAL_MECHANISM_OF_IFN_STIMUL...  11
# 5950  trained_PC1      REACTOME_RHO_GTPASES_ACTIVATE_WASPS_AND_WAVES  10
# 1729          PC2                      REACTOME_INTERFERON_SIGNALING  11
# 1632          PC2                           REACTOME_CILIUM_ASSEMBLY  11
# 5316          PC1      REACTOME_RHO_GTPASES_ACTIVATE_WASPS_AND_WAVES  10
# 1672          PC2  REACTOME_DISEASES_OF_SIGNAL_TRANSDUCTION_BY_GR...  11
# 1839          PC2                      REACTOME_SARS_COV_1_INFECTION  11
# 1315          PC1                           REACTOME_CILIUM_ASSEMBLY  11
# 2063  trained_PC1                      REACTOME_MEMBRANE_TRAFFICKING  11
# 1482          PC1                         REACTOME_RAC3_GTPASE_CYCLE  11
# 1282          PC1  REACTOME_ANTIMICROBIAL_MECHANISM_OF_IFN_STIMUL...  11
# 1720          PC2  REACTOME_HSP90_CHAPERONE_CYCLE_FOR_STEROID_HOR...  11
# 887   trained_PC1              REACTOME_SARS_COV_1_HOST_INTERACTIONS  11
# 1355          PC1  REACTOME_DISEASES_OF_SIGNAL_TRANSDUCTION_BY_GR...  11
# 1618          PC2  REACTOME_CARGO_TRAFFICKING_TO_THE_PERICILIARY_...  11
# 1594          PC2  REACTOME_ANCHORING_OF_THE_BASAL_BODY_TO_THE_PL...  11
# 5111          PC1      REACTOME_CELLULAR_RESPONSE_TO_CHEMICAL_STRESS  10
# 1522          PC1                      REACTOME_SARS_COV_1_INFECTION  11
# 5745  trained_PC1      REACTOME_CELLULAR_RESPONSE_TO_CHEMICAL_STRESS  10
# 5803  trained_PC1                      REACTOME_EPH_EPHRIN_SIGNALING  10
#
#       pearson_r     pearson_p  spearman_r  spearman_p  fold
# 1599   0.984482  4.134918e-08    0.936364    0.000022     1
# 5950   0.982316  4.188741e-07    0.878788    0.000814     4
# 1729   0.981267  9.603149e-08    0.909091    0.000106     1
# 1632   0.980964  1.031896e-07    0.863636    0.000612     1
# 5316   0.980240  6.512863e-07    0.878788    0.000814     4
# 1672   0.978001  1.970156e-07    0.945455    0.000011     1
# 1839   0.977730  2.081088e-07    0.881818    0.000330     1
# 1315   0.977729  2.081418e-07    0.863636    0.000612     1
# 2063   0.976197  2.801612e-07    0.809091    0.002559     1
# 1482   0.976153  2.824609e-07    0.890909    0.000233     1
# 1282   0.976063  2.872552e-07    0.900000    0.000160     1
# 1720   0.975948  2.934807e-07    0.900000    0.000160     1
# 887    0.975833  2.997901e-07    0.845455    0.001045     0
# 1355   0.975445  3.218620e-07    0.909091    0.000106     1
# 1618   0.975386  3.253638e-07    0.918182    0.000067     1
# 1594   0.975273  3.321008e-07    0.900000    0.000160     1
# 5111   0.975137  1.622551e-06    0.866667    0.001174     4
# 1522   0.975064  3.447804e-07    0.836364    0.001333     1
# 5745   0.974490  1.796541e-06    0.866667    0.001174     4
# 5803   0.973884  1.972167e-06    0.903030    0.000344     4

# %% [markdown]
# #### Cross modality pathway correlation

# %%
### Correlate tissue pc values with plasma pathway scores 
plasma_pathways = plasma_scores.copy()
tissue_pc_plasma_pathways = tissue_pc.merge(
    plasma_pathways,
    on="patient",
    how="inner"
)
cross_tissue_to_plasma = []

for fold in range(5):

    fold_df = tissue_pc_plasma_pathways[
        tissue_pc_plasma_pathways["fold"] == fold
    ]

    result = correlate_pc_pathways(fold_df)
    result["fold"] = fold

    cross_tissue_to_plasma.append(result)

cross_tissue_to_plasma = pd.concat(
    cross_tissue_to_plasma,
    ignore_index=True
)
cross_tissue_to_plasma.sort_values(
    "pearson_r",
    ascending=False
).head(20)
# Out:
#                PC                                            pathway   n  \
# 5950  trained_PC1      REACTOME_RHO_GTPASES_ACTIVATE_WASPS_AND_WAVES  10
# 4404          PC2                         REACTOME_SIGNALING_BY_VEGF  10
# 1429          PC1                      REACTOME_MEMBRANE_TRAFFICKING  11
# 3414  trained_PC1      REACTOME_RHO_GTPASES_ACTIVATE_WASPS_AND_WAVES  10
# 2063  trained_PC1                      REACTOME_MEMBRANE_TRAFFICKING  11
# 5803  trained_PC1                      REACTOME_EPH_EPHRIN_SIGNALING  10
# 1306          PC1             REACTOME_CELLULAR_RESPONSES_TO_STIMULI  11
# 1355          PC1  REACTOME_DISEASES_OF_SIGNAL_TRANSDUCTION_BY_GR...  11
# 1333          PC1       REACTOME_CYTOKINE_SIGNALING_IN_IMMUNE_SYSTEM  11
# 1315          PC1                           REACTOME_CILIUM_ASSEMBLY  11
# 2810          PC1                        REACTOME_SIGNALING_BY_NTRKS  10
# 5744  trained_PC1             REACTOME_CELLULAR_RESPONSES_TO_STIMULI  10
# 1967  trained_PC1       REACTOME_CYTOKINE_SIGNALING_IN_IMMUNE_SYSTEM  11
# 1546          PC1  REACTOME_SIGNALING_BY_RHO_GTPASES_MIRO_GTPASES...  11
# 1461          PC1      REACTOME_ORGANELLE_BIOGENESIS_AND_MAINTENANCE  11
# 3416  trained_PC1                      REACTOME_RHO_GTPASE_EFFECTORS  10
# 4721  trained_PC1                         REACTOME_SIGNALING_BY_VEGF  10
# 1318          PC1             REACTOME_CLATHRIN_MEDIATED_ENDOCYTOSIS  11
# 5745  trained_PC1      REACTOME_CELLULAR_RESPONSE_TO_CHEMICAL_STRESS  10
# 5781  trained_PC1  REACTOME_DENGUE_VIRUS_GENOME_TRANSLATION_AND_R...  10
#
#       pearson_r     pearson_p  spearman_r    spearman_p  fold
# 5950   0.988648  7.167201e-08    0.878788  8.138621e-04     4
# 4404   0.980438  6.257095e-07    0.866667  1.173538e-03     3
# 1429   0.979987  1.290613e-07    0.863636  6.116939e-04     1
# 3414   0.979454  7.605898e-07    0.939394  5.484053e-05     2
# 2063   0.978481  1.784986e-07    0.854545  8.066742e-04     1
# 5803   0.978414  9.255702e-07    0.903030  3.436122e-04     4
# 1306   0.978179  1.900008e-07    0.927273  3.973774e-05     1
# 1355   0.977778  2.060906e-07    0.945455  1.118304e-05     1
# 1333   0.977276  2.277207e-07    0.972727  5.142177e-07     1
# 1315   0.977260  2.284348e-07    0.863636  6.116939e-04     1
# 2810   0.976695  1.254719e-06    0.927273  1.120345e-04     2
# 5744   0.976337  1.333135e-06    0.927273  1.120345e-04     4
# 1967   0.974742  3.650977e-07    0.990909  3.762572e-09     1
# 1546   0.974374  3.894956e-07    0.963636  1.852040e-06     1
# 1461   0.974168  4.036633e-07    0.863636  6.116939e-04     1
# 3416   0.973904  1.966023e-06    0.903030  3.436122e-04     2
# 4721   0.973435  2.110081e-06    0.866667  1.173538e-03     3
# 1318   0.973362  4.629476e-07    0.872727  4.546151e-04     1
# 5745   0.973023  2.242978e-06    0.866667  1.173538e-03     4
# 5781   0.973017  2.244844e-06    0.903030  3.436122e-04     4

# %%
### Correlate plasma embedding/PC scores with tissue pathway scores
#### this is the important one
tissue_pathways = tissue_scores.copy()
plasma_pc_tissue_pathways = plasma_pc.merge(
    tissue_scores,
    on="patient",
    how="inner"
)

cross_plasma_to_tissue = []

for fold in range(5):

    fold_df = plasma_pc_tissue_pathways[
        plasma_pc_tissue_pathways["fold"] == fold
    ]

    result = correlate_pc_pathways(fold_df)
    result["fold"] = fold

    cross_plasma_to_tissue.append(result)

cross_plasma_to_tissue = pd.concat(
    cross_plasma_to_tissue,
    ignore_index=True
)

# %%
tissue_results = add_fdr(tissue_results)
plasma_results = add_fdr(plasma_results)

cross_tissue_to_plasma = add_fdr(cross_tissue_to_plasma)
cross_plasma_to_tissue = add_fdr(cross_plasma_to_tissue)

# %%
cross_plasma_to_tissue.sort_values(
    ["pearson_fdr",'spearman_fdr'],
    ascending=True
).head(20)
# Out:
#                 PC                                            pathway   n  \
# 13196          PC1                         REACTOME_RND2_GTPASE_CYCLE  10
# 14770  trained_PC1                         REACTOME_RND2_GTPASE_CYCLE  10
# 130            PC1                        REACTOME_DAP12_INTERACTIONS  11
# 131            PC1                           REACTOME_DAP12_SIGNALING  11
# 1997   trained_PC1                REACTOME_NERVOUS_SYSTEM_DEVELOPMENT  11
# 2217   trained_PC1  REACTOME_SIGNALING_BY_CSF1_M_CSF_IN_MYELOID_CELLS  11
# 643            PC1  REACTOME_SIGNALING_BY_CSF1_M_CSF_IN_MYELOID_CELLS  11
# 1705   trained_PC1                           REACTOME_DAP12_SIGNALING  11
# 12947          PC1               REACTOME_LYSOSOME_VESICLE_BIOGENESIS  10
# 14521  trained_PC1               REACTOME_LYSOSOME_VESICLE_BIOGENESIS  10
# 330            PC1  REACTOME_INTERLEUKIN_3_INTERLEUKIN_5_AND_GM_CS...  11
# 2298   trained_PC1                             REACTOME_TCR_SIGNALING  11
# 1117           PC2  REACTOME_INTERLEUKIN_3_INTERLEUKIN_5_AND_GM_CS...  11
# 1704   trained_PC1                        REACTOME_DAP12_INTERACTIONS  11
# 2322   trained_PC1       REACTOME_TRANSCRIPTIONAL_REGULATION_BY_RUNX3  11
# 2122   trained_PC1            REACTOME_REGULATION_OF_SIGNALING_BY_CBL  11
# 4936   trained_PC1                     REACTOME_FATTY_ACID_METABOLISM  11
# 227            PC1                            REACTOME_FLT3_SIGNALING  11
# 548            PC1            REACTOME_REGULATION_OF_SIGNALING_BY_CBL  11
# 1430           PC2  REACTOME_SIGNALING_BY_CSF1_M_CSF_IN_MYELOID_CELLS  11
#
#        pearson_r  pearson_p  spearman_r  spearman_p  fold  pearson_fdr  \
# 13196   0.948392   0.000029    0.939394    0.000055     4     0.229443
# 14770   0.951268   0.000023    0.939394    0.000055     4     0.229443
# 130     0.908864   0.000107    0.800000    0.003110     0     0.560086
# 131     0.897464   0.000178    0.827273    0.001677     0     0.701932
# 1997    0.889622   0.000246    0.809091    0.002559     0     0.716786
# 2217   -0.886876   0.000273   -0.781818    0.004473     0     0.716786
# 643     0.862508   0.000634    0.909091    0.000106     0     0.872331
# 1705   -0.860746   0.000669   -0.909091    0.000106     0     0.872331
# 12947  -0.736377   0.015153   -0.927273    0.000112     4     0.872331
# 14521  -0.746953   0.013045   -0.927273    0.000112     4     0.872331
# 330     0.789516   0.003851    0.900000    0.000160     0     0.872331
# 2298   -0.775054   0.005078   -0.900000    0.000160     0     0.872331
# 1117   -0.793924   0.003526   -0.890909    0.000233     0     0.872331
# 1704   -0.838960   0.001246   -0.890909    0.000233     0     0.872331
# 2322   -0.721316   0.012233   -0.890909    0.000233     0     0.872331
# 2122   -0.785503   0.004167   -0.881818    0.000330     0     0.872331
# 4936    0.785509   0.004166    0.881818    0.000330     1     0.872331
# 227     0.811259   0.002439    0.854545    0.000807     0     0.872331
# 548     0.833284   0.001443    0.854545    0.000807     0     0.872331
# 1430   -0.721530   0.012194   -0.854545    0.000807     0     0.872331
#
#        spearman_fdr
# 13196      0.293904
# 14770      0.293904
# 130        0.499573
# 131        0.488807
# 1997       0.499573
# 2217       0.536111
# 643        0.293904
# 1705       0.293904
# 12947      0.293904
# 14521      0.293904
# 330        0.314744
# 2298       0.314744
# 1117       0.334057
# 1704       0.334057
# 2322       0.334057
# 2122       0.399758
# 4936       0.399758
# 227        0.421825
# 548        0.421825
# 1430       0.421825

# %%
summary_plasma_to_tissue = (
    cross_plasma_to_tissue
    .groupby(["PC", "pathway"])
    .agg(
        # Pearson
        pearson_mean_abs_r=("pearson_r", lambda x: x.abs().mean()),
        pearson_median_abs_r=("pearson_r", lambda x: x.abs().median()),
        pearson_min_abs_r=("pearson_r", lambda x: x.abs().min()),
        pearson_max_abs_r=("pearson_r", lambda x: x.abs().max()),

        # Spearman
        spearman_mean_abs_r=("spearman_r", lambda x: x.abs().mean()),
        spearman_median_abs_r=("spearman_r", lambda x: x.abs().median()),
        spearman_min_abs_r=("spearman_r", lambda x: x.abs().min()),
        spearman_max_abs_r=("spearman_r", lambda x: x.abs().max()),

        n_folds=("fold", "nunique"),
    )
    .reset_index()
)

print(summary_plasma_to_tissue)
# Out:
#                PC                                            pathway  \
# 0             PC1    REACTOME_ABC_FAMILY_PROTEINS_MEDIATED_TRANSPORT
# 1             PC1                 REACTOME_ABC_TRANSPORTER_DISORDERS
# 2             PC1  REACTOME_ABORTIVE_ELONGATION_OF_HIV_1_TRANSCRI...
# 3             PC1   REACTOME_ACTIVATION_OF_AMPK_DOWNSTREAM_OF_NMDARS
# 4             PC1  REACTOME_ACTIVATION_OF_ANTERIOR_HOX_GENES_IN_H...
# ...           ...                                                ...
# 3143  trained_PC2  REACTOME_VASOPRESSIN_REGULATES_RENAL_WATER_HOM...
# 3144  trained_PC2     REACTOME_VEGFR2_MEDIATED_VASCULAR_PERMEABILITY
# 3145  trained_PC2      REACTOME_VIF_MEDIATED_DEGRADATION_OF_APOBEC3G
# 3146  trained_PC2             REACTOME_VIRAL_MESSENGER_RNA_SYNTHESIS
# 3147  trained_PC2                  REACTOME_VISUAL_PHOTOTRANSDUCTION
#
#       pearson_mean_abs_r  pearson_median_abs_r  pearson_min_abs_r  \
# 0               0.272696              0.189130           0.049162
# 1               0.289873              0.318773           0.000635
# 2               0.326713              0.286731           0.103803
# 3               0.209539              0.128949           0.004744
# 4               0.313935              0.384135           0.057619
# ...                  ...                   ...                ...
# 3143            0.273748              0.313559           0.018308
# 3144            0.283184              0.243518           0.072052
# 3145            0.278699              0.285067           0.087874
# 3146            0.278461              0.301250           0.000058
# 3147            0.297564              0.308585           0.159141
#
#       pearson_max_abs_r  spearman_mean_abs_r  spearman_median_abs_r  \
# 0              0.586027             0.365455               0.333333
# 1              0.578804             0.389091               0.400000
# 2              0.610953             0.295152               0.272727
# 3              0.598627             0.339394               0.381818
# 4              0.534012             0.195152               0.151515
# ...                 ...                  ...                    ...
# 3143           0.403225             0.223636               0.245455
# 3144           0.500203             0.286061               0.245455
# 3145           0.468913             0.335758               0.369697
# 3146           0.487467             0.323030               0.263636
# 3147           0.479080             0.255152               0.284848
#
#       spearman_min_abs_r  spearman_max_abs_r  n_folds
# 0               0.187879            0.590909        5
# 1               0.139394            0.600000        5
# 2               0.139394            0.515152        5
# 3               0.127273            0.418182        5
# 4               0.066667            0.445455        5
# ...                  ...                 ...      ...
# 3143            0.030303            0.381818        5
# 3144            0.018182            0.612121        5
# 3145            0.151515            0.536364        5
# 3146            0.145455            0.515152        5
# 3147            0.066667            0.442424        5
#
# [3148 rows x 11 columns]

# %%
summary_plasma_to_tissue[
    (summary_plasma_to_tissue["n_folds"] == 5)
].sort_values(['pearson_mean_abs_r'],
    ascending=False
).head(10)
# Out:
#                PC                                            pathway  \
# 2255  trained_PC1                       REACTOME_SIGNALING_BY_TGFBR3
# 44            PC1                         REACTOME_ATTENUATION_PHASE
# 1618  trained_PC1                         REACTOME_ATTENUATION_PHASE
# 1956  trained_PC1          REACTOME_MITF_M_DEPENDENT_GENE_EXPRESSION
# 587           PC1                 REACTOME_RHO_GTPASES_ACTIVATE_PKNS
# 237           PC1  REACTOME_FORMATION_OF_THE_DYSTROPHIN_GLYCOPROT...
# 1873  trained_PC1            REACTOME_HSF1_DEPENDENT_TRANSACTIVATION
# 1104          PC2                        REACTOME_INTEGRIN_SIGNALING
# 1468          PC2                       REACTOME_SIGNALING_BY_TGFBR3
# 1875  trained_PC1  REACTOME_IMMUNOREGULATORY_INTERACTIONS_BETWEEN...
#
#       pearson_mean_abs_r  pearson_median_abs_r  pearson_min_abs_r  \
# 2255            0.632512              0.678648           0.461482
# 44              0.578437              0.722671           0.341362
# 1618            0.557028              0.722329           0.072263
# 1956            0.535854              0.501983           0.368541
# 587             0.533578              0.491494           0.407047
# 237             0.529575              0.542036           0.277294
# 1873            0.529267              0.608124           0.248696
# 1104            0.526960              0.492921           0.355861
# 1468            0.523637              0.511116           0.319161
# 1875            0.523617              0.521378           0.405176
#
#       pearson_max_abs_r  spearman_mean_abs_r  spearman_median_abs_r  \
# 2255           0.788625             0.561212               0.527273
# 44             0.744046             0.461212               0.527273
# 1618           0.840725             0.477576               0.490909
# 1956           0.756592             0.510909               0.478788
# 587            0.795590             0.572121               0.572727
# 237            0.805890             0.522424               0.409091
# 1873           0.810353             0.438182               0.427273
# 1104           0.774632             0.458788               0.466667
# 1468           0.657222             0.503030               0.527273
# 1875           0.601588             0.480606               0.442424
#
#       spearman_min_abs_r  spearman_max_abs_r  n_folds
# 2255            0.254545            0.818182        5
# 44              0.018182            0.754545        5
# 1618            0.090909            0.772727        5
# 1956            0.381818            0.793939        5
# 587             0.390909            0.757576        5
# 237             0.260606            0.866667        5
# 1873            0.006061            0.800000        5
# 1104            0.030303            0.700000        5
# 1468            0.218182            0.690909        5
# 1875            0.406061            0.618182        5

# %%
summary_plasma_to_tissue[
    (summary_plasma_to_tissue["n_folds"] == 5)
].sort_values(['pearson_mean_abs_r'],
    ascending=False
).head(10)
# Out:
#        PC                                            pathway  \
# 681   PC1                       REACTOME_SIGNALING_BY_TGFBR3
# 1024  PC2  REACTOME_FORMATION_OF_THE_DYSTROPHIN_GLYCOPROT...
# 268   PC1          REACTOME_GPVI_MEDIATED_ACTIVATION_CASCADE
# 1169  PC2          REACTOME_MITF_M_DEPENDENT_GENE_EXPRESSION
# 1480  PC2                 REACTOME_SMOOTH_MUSCLE_CONTRACTION
# 1055  PC2          REACTOME_GPVI_MEDIATED_ACTIVATION_CASCADE
# 918   PC2                           REACTOME_DAP12_SIGNALING
# 44    PC1                         REACTOME_ATTENUATION_PHASE
# 299   PC1            REACTOME_HSF1_DEPENDENT_TRANSACTIVATION
# 917   PC2                        REACTOME_DAP12_INTERACTIONS
#
#       pearson_mean_abs_r  pearson_median_abs_r  pearson_min_abs_r  \
# 681             0.597024              0.644610           0.434148
# 1024            0.540794              0.635282           0.170626
# 268             0.537470              0.667339           0.216210
# 1169            0.527610              0.519527           0.343348
# 1480            0.522015              0.511161           0.248521
# 1055            0.511126              0.409082           0.287898
# 918             0.507388              0.469609           0.085163
# 44              0.506781              0.624830           0.129337
# 299             0.500394              0.519347           0.119631
# 917             0.500293              0.531483           0.007335
#
#       pearson_max_abs_r  spearman_mean_abs_r  spearman_median_abs_r  \
# 681            0.725121             0.471515               0.527273
# 1024           0.819541             0.522424               0.709091
# 268            0.740877             0.375152               0.563636
# 1169           0.737780             0.533333               0.612121
# 1480           0.918082             0.501818               0.490909
# 1055           0.757955             0.443636               0.545455
# 918            0.836301             0.482424               0.590909
# 44             0.751380             0.379394               0.427273
# 299            0.771424             0.341212               0.369697
# 917            0.854329             0.570909               0.645455
#
#       spearman_min_abs_r  spearman_max_abs_r  n_folds
# 681             0.248485            0.690909        5
# 1024            0.115152            0.733333        5
# 268             0.030303            0.609091        5
# 1169            0.190909            0.721212        5
# 1480            0.327273            0.757576        5
# 1055            0.006061            0.745455        5
# 918             0.066667            0.809091        5
# 44              0.187879            0.539394        5
# 299             0.163636            0.581818        5
# 917             0.115152            0.854545        5

# %%
top_pearson = summary_plasma_to_tissue[
    (summary_plasma_to_tissue["n_folds"] == 5)
].sort_values(['pearson_mean_abs_r'],
    ascending=False
).head(5)['pathway'].tolist()

# %%
print(top_pearson)
# Out:
# ['REACTOME_SIGNALING_BY_TGFBR3', 'REACTOME_GPVI_MEDIATED_ACTIVATION_CASCADE', 'REACTOME_SMOOTH_MUSCLE_CONTRACTION', 'REACTOME_CD209_DC_SIGN_SIGNALING', 'REACTOME_ATTENUATION_PHASE']

# %%
tissue_pc_plasma_pathways.head()
# Out:
#      patient modality       PC1       PC2  fold  \
# 0  Sample 15   Tissue  0.007993 -0.147167     0
# 1  Sample 17   Tissue  0.015316 -0.152174     0
# 2  Sample 28   Tissue -0.061666 -0.085500     0
# 3  Sample 29   Tissue -0.116348 -0.038279     0
# 4  Sample 34   Tissue -0.003384 -0.137829     0
#
#    REACTOME_ABC_FAMILY_PROTEINS_MEDIATED_TRANSPORT  \
# 0                                         0.204250
# 1                                         0.026838
# 2                                         0.159901
# 3                                         0.268874
# 4                                         0.197636
#
#    REACTOME_ABC_TRANSPORTER_DISORDERS  \
# 0                            0.214317
# 1                            0.033465
# 2                            0.154310
# 3                            0.266008
# 4                            0.194783
#
#    REACTOME_ACTIVATION_OF_APC_C_AND_APC_C_CDC20_MEDIATED_DEGRADATION_OF_MITOTIC_PROTEINS  \
# 0                                           0.168489
# 1                                          -0.005519
# 2                                           0.112480
# 3                                           0.248693
# 4                                           0.152219
#
#    REACTOME_ACTIVATION_OF_NF_KAPPAB_IN_B_CELLS  \
# 0                                     0.149088
# 1                                    -0.004788
# 2                                     0.114566
# 3                                     0.235441
# 4                                     0.132832
#
#    REACTOME_ADAPTIVE_IMMUNE_SYSTEM  ...  \
# 0                         0.164303  ...
# 1                         0.180325  ...
# 2                         0.221838  ...
# 3                         0.238812  ...
# 4                         0.164300  ...
#
#    REACTOME_TRANS_GOLGI_NETWORK_VESICLE_BUDDING  \
# 0                                     -0.035744
# 1                                      0.033403
# 2                                      0.086650
# 3                                      0.123468
# 4                                     -0.043331
#
#    REACTOME_UBIQUITIN_DEPENDENT_DEGRADATION_OF_CYCLIN_D  \
# 0                                           0.168489
# 1                                          -0.005519
# 2                                           0.112480
# 3                                           0.248693
# 4                                           0.152219
#
#    REACTOME_UBIQUITIN_MEDIATED_DEGRADATION_OF_PHOSPHORYLATED_CDC25A  \
# 0                                           0.138505
# 1                                          -0.012768
# 2                                           0.113977
# 3                                           0.225208
# 4                                           0.128396
#
#    REACTOME_UB_SPECIFIC_PROCESSING_PROTEASES  REACTOME_UCH_PROTEINASES  \
# 0                                   0.100617                  0.159640
# 1                                  -0.019499                  0.016425
# 2                                   0.100253                  0.133214
# 3                                   0.225463                  0.243030
# 4                                   0.087808                  0.139243
#
#    REACTOME_UNFOLDED_PROTEIN_RESPONSE_UPR  \
# 0                                0.036210
# 1                                0.078718
# 2                                0.133493
# 3                                0.165831
# 4                                0.115290
#
#    REACTOME_VESICLE_MEDIATED_TRANSPORT  \
# 0                             0.158433
# 1                             0.205294
# 2                             0.229199
# 3                             0.241994
# 4                             0.159399
#
#    REACTOME_VIF_MEDIATED_DEGRADATION_OF_APOBEC3G  \
# 0                                       0.128664
# 1                                      -0.021473
# 2                                       0.124562
# 3                                       0.221681
# 4                                       0.118255
#
#    REACTOME_VIRAL_INFECTION_PATHWAYS  REACTOME_VISUAL_PHOTOTRANSDUCTION
# 0                           0.195283                           0.390870
# 1                           0.191556                           0.366004
# 2                           0.231783                           0.271223
# 3                           0.262423                           0.164421
# 4                           0.220068                           0.403327
#
# [5 rows x 322 columns]

# %%
pc1_untrained = cross_plasma_to_tissue[
    cross_plasma_to_tissue["PC"] == "PC1"
].copy()

pc1_trained = cross_plasma_to_tissue[
    cross_plasma_to_tissue["PC"] == "trained_PC1"
].copy()
pc1_untrained["abs_r"] = pc1_untrained["pearson_r"].abs()
pc1_trained["abs_r"] = pc1_trained["pearson_r"].abs()
pc1_comparison = pc1_untrained[
    ["pathway", "fold", "abs_r"]
].merge(
    pc1_trained[
        ["pathway", "fold", "abs_r"]
    ],
    on=["pathway", "fold"],
    suffixes=("_untrained", "_trained")
)

pc1_comparison["delta_abs_r"] = (
    pc1_comparison["abs_r_trained"]
    - pc1_comparison["abs_r_untrained"]
)

# %%
pc1_comparison.head()
# Out:
#                                              pathway  fold  abs_r_untrained  \
# 0    REACTOME_ABC_FAMILY_PROTEINS_MEDIATED_TRANSPORT     0         0.117704
# 1                 REACTOME_ABC_TRANSPORTER_DISORDERS     0         0.468951
# 2  REACTOME_ABORTIVE_ELONGATION_OF_HIV_1_TRANSCRI...     0         0.103803
# 3   REACTOME_ACTIVATION_OF_AMPK_DOWNSTREAM_OF_NMDARS     0         0.598627
# 4  REACTOME_ACTIVATION_OF_ANTERIOR_HOX_GENES_IN_H...     0         0.384135
#
#    abs_r_trained  delta_abs_r
# 0       0.108809    -0.008895
# 1       0.382022    -0.086929
# 2       0.156075     0.052273
# 3       0.667692     0.069066
# 4       0.574246     0.190111

# %%
top_pearson_PC1 = (
    cross_plasma_to_tissue[(cross_plasma_to_tissue["PC"] == "PC1")]
    .groupby("pathway")
    .agg(
        mean_abs_r=("pearson_r", lambda x: x.abs().mean())
    )
    .sort_values("mean_abs_r", ascending=False)
    
    #.index
)
top_pearson_PC1_index = top_pearson_PC1[(top_pearson_PC1["mean_abs_r"] > 0.45)].index
top_pearson_PC2 = (
    cross_plasma_to_tissue[(cross_plasma_to_tissue["PC"] == "PC2")]
    .groupby("pathway")
    .agg(
        mean_abs_r=("pearson_r", lambda x: x.abs().mean())
    )
    .sort_values("mean_abs_r", ascending=False)

   # .index
)
top_pearson_PC2_index = top_pearson_PC2[(top_pearson_PC2["mean_abs_r"] > 0.45)].index
top_pearson_PC1_trained = (
    cross_plasma_to_tissue[(cross_plasma_to_tissue["PC"] == "trained_PC1")]
    .groupby("pathway")
    .agg(
        mean_abs_r=("pearson_r", lambda x: x.abs().mean())
    )
    .sort_values("mean_abs_r", ascending=False)
    
    #.index
)
top_pearson_PC1_trained_index = top_pearson_PC1_trained[(top_pearson_PC1_trained["mean_abs_r"] > 0.45)].index
top_pearson_PC2_trained = (
    cross_plasma_to_tissue[(cross_plasma_to_tissue["PC"] == "trained_PC2")]
    .groupby("pathway")
    .agg(
        mean_abs_r=("pearson_r", lambda x: x.abs().mean())
    )
    .sort_values("mean_abs_r", ascending=False)
   
   # .index
)
top_pearson_PC2_trained_index = top_pearson_PC2_trained[(top_pearson_PC2_trained["mean_abs_r"] > 0.45)].index

pc1_comparison = (
    top_pearson_PC1
    .rename(columns={"mean_abs_r": "mean_abs_r_untrained"})
    .reset_index()
    .merge(
        top_pearson_PC1_trained
        .rename(columns={"mean_abs_r": "mean_abs_r_trained"})
        .reset_index(),
        on="pathway"
    )
)

pc1_comparison["delta_mean_abs_r"] = (
    pc1_comparison["mean_abs_r_trained"]
    - pc1_comparison["mean_abs_r_untrained"]
)

pc1_comparison = pc1_comparison.sort_values(
    "delta_mean_abs_r",
    ascending=False
)

print(pc1_comparison.head(10))
print(top_pearson_PC1.index)
print(top_pearson_PC1_index)
print(top_pearson_PC2_index)
print(top_pearson_PC1_trained_index)
print(top_pearson_PC2_trained_index)

plot_data_PC2 = cross_plasma_to_tissue[
    (cross_plasma_to_tissue["PC"] == "PC2") &
    (cross_plasma_to_tissue["pathway"].isin(top_pearson_PC2_index))
].copy()

plot_data_PC2["abs_pearson_r"] = plot_data_PC2["pearson_r"].abs()

plot_df_PC2 = plot_data_PC2.pivot(
    index="pathway",
    columns="fold",
    values="abs_pearson_r"
)
#plot_df_PC2
# Out:
#                                                pathway  mean_abs_r_untrained  \
# 465                REACTOME_G2_M_DNA_DAMAGE_CHECKPOINT              0.283471
# 373  REACTOME_INITIATION_OF_NUCLEAR_ENVELOPE_NE_REF...              0.310512
# 738  REACTOME_ADP_SIGNALLING_THROUGH_P2Y_PURINOCEPT...              0.175512
# 352                 REACTOME_APOPTOTIC_EXECUTION_PHASE              0.316883
# 86           REACTOME_MITF_M_DEPENDENT_GENE_EXPRESSION              0.419737
# 4                         REACTOME_SIGNALING_BY_TGFBR3              0.516872
# 434                     REACTOME_BIOLOGICAL_OXIDATIONS              0.290585
# 591                    REACTOME_ESR_MEDIATED_SIGNALING              0.250445
# 526  REACTOME_DEFECTIVE_INTRINSIC_PATHWAY_FOR_APOPT...              0.266057
# 351    REACTOME_PHASE_I_FUNCTIONALIZATION_OF_COMPOUNDS              0.317378
#
#      mean_abs_r_trained  delta_mean_abs_r
# 465            0.407525          0.124054
# 373            0.431698          0.121186
# 738            0.294448          0.118936
# 352            0.433437          0.116554
# 86             0.535854          0.116117
# 4              0.632512          0.115639
# 434            0.404642          0.114057
# 591            0.359579          0.109134
# 526            0.374302          0.108245
# 351            0.425328          0.107950
# Index(['REACTOME_ATTENUATION_PHASE', 'REACTOME_RHO_GTPASES_ACTIVATE_PKNS',
#        'REACTOME_FORMATION_OF_THE_DYSTROPHIN_GLYCOPROTEIN_COMPLEX_DGC',
#        'REACTOME_BACTERIAL_INFECTION_PATHWAYS', 'REACTOME_SIGNALING_BY_TGFBR3',
#        'REACTOME_GPVI_MEDIATED_ACTIVATION_CASCADE',
#        'REACTOME_DAP12_INTERACTIONS',
#        'REACTOME_HSF1_DEPENDENT_TRANSACTIVATION', 'REACTOME_DAP12_SIGNALING',
#        'REACTOME_CD209_DC_SIGN_SIGNALING',
#        ...
#        'REACTOME_COMPLEX_IV_ASSEMBLY', 'REACTOME_MAPK1_MAPK3_SIGNALING',
#        'REACTOME_SYNTHESIS_OF_PC',
#        'REACTOME_BIOSYNTHESIS_OF_THE_N_GLYCAN_PRECURSOR_DOLICHOL_LIPID_LINKED_OLIGOSACCHARIDE_LLO_AND_TRANSFER_TO_A_NASCENT_PROTEIN',
#        'REACTOME_DEGRADATION_OF_BETA_CATENIN_BY_THE_DESTRUCTION_COMPLEX',
#        'REACTOME_RNA_POLYMERASE_I_TRANSCRIPTION_INITIATION',
#        'REACTOME_SYNTHESIS_OF_SUBSTRATES_IN_N_GLYCAN_BIOSYTHESIS',
#        'REACTOME_TRNA_MODIFICATION_IN_THE_NUCLEUS_AND_CYTOSOL',
#        'REACTOME_ION_TRANSPORT_BY_P_TYPE_ATPASES',
#        'REACTOME_MAPK_FAMILY_SIGNALING_CASCADES'],
#       dtype='str', name='pathway', length=787)
# Index(['REACTOME_ATTENUATION_PHASE', 'REACTOME_RHO_GTPASES_ACTIVATE_PKNS',
#        'REACTOME_FORMATION_OF_THE_DYSTROPHIN_GLYCOPROTEIN_COMPLEX_DGC',
#        'REACTOME_BACTERIAL_INFECTION_PATHWAYS', 'REACTOME_SIGNALING_BY_TGFBR3',
#        'REACTOME_GPVI_MEDIATED_ACTIVATION_CASCADE',
#        'REACTOME_DAP12_INTERACTIONS',
#        'REACTOME_HSF1_DEPENDENT_TRANSACTIVATION', 'REACTOME_DAP12_SIGNALING',
#        'REACTOME_CD209_DC_SIGN_SIGNALING',
#        'REACTOME_IMMUNOREGULATORY_INTERACTIONS_BETWEEN_A_LYMPHOID_AND_A_NON_LYMPHOID_CELL',
#        'REACTOME_RESPIRATORY_SYNCYTIAL_VIRUS_RSV_ATTACHMENT_AND_ENTRY',
#        'REACTOME_REGULATION_OF_CDH1_GENE_TRANSCRIPTION',
#        'REACTOME_OXIDATIVE_STRESS_INDUCED_SENESCENCE',
#        'REACTOME_CLASS_A_1_RHODOPSIN_LIKE_RECEPTORS',
#        'REACTOME_CRISTAE_FORMATION',
#        'REACTOME_PEPTIDE_LIGAND_BINDING_RECEPTORS',
#        'REACTOME_RESPIRATORY_SYNCYTIAL_VIRUS_INFECTION_PATHWAY',
#        'REACTOME_EARLY_SARS_COV_2_INFECTION_EVENTS',
#        'REACTOME_METABOLIC_DISORDERS_OF_BIOLOGICAL_OXIDATION_ENZYMES',
#        'REACTOME_REGULATION_OF_PLK1_ACTIVITY_AT_G2_M_TRANSITION',
#        'REACTOME_NOD1_2_SIGNALING_PATHWAY',
#        'REACTOME_NERVOUS_SYSTEM_DEVELOPMENT',
#        'REACTOME_SIGNALING_BY_INTERLEUKINS',
#        'REACTOME_ELASTIC_FIBRE_FORMATION',
#        'REACTOME_EPH_EPHRIN_MEDIATED_REPULSION_OF_CELLS',
#        'REACTOME_ORGANELLE_BIOGENESIS_AND_MAINTENANCE',
#        'REACTOME_NEUTROPHIL_DEGRANULATION',
#        'REACTOME_AURKA_ACTIVATION_BY_TPX2',
#        'REACTOME_RECRUITMENT_OF_MITOTIC_CENTROSOME_PROTEINS_AND_COMPLEXES',
#        'REACTOME_FC_EPSILON_RECEPTOR_FCERI_SIGNALING',
#        'REACTOME_ANCHORING_OF_THE_BASAL_BODY_TO_THE_PLASMA_MEMBRANE',
#        'REACTOME_CELL_SURFACE_INTERACTIONS_AT_THE_VASCULAR_WALL',
#        'REACTOME_GLYCOSAMINOGLYCAN_PROTEIN_LINKAGE_REGION_BIOSYNTHESIS',
#        'REACTOME_RND3_GTPASE_CYCLE',
#        'REACTOME_INTERLEUKIN_4_AND_INTERLEUKIN_13_SIGNALING',
#        'REACTOME_SIGNALING_BY_THE_B_CELL_RECEPTOR_BCR',
#        'REACTOME_NUCLEOTIDE_SALVAGE',
#        'REACTOME_CONSTITUTIVE_SIGNALING_BY_ABERRANT_PI3K_IN_CANCER',
#        'REACTOME_RHOQ_GTPASE_CYCLE',
#        'REACTOME_FCERI_MEDIATED_CA_2_MOBILIZATION',
#        'REACTOME_ANTIGEN_ACTIVATES_B_CELL_RECEPTOR_BCR_LEADING_TO_GENERATION_OF_SECOND_MESSENGERS',
#        'REACTOME_SMOOTH_MUSCLE_CONTRACTION', 'REACTOME_DARPP_32_EVENTS',
#        'REACTOME_NUCLEOTIDE_BINDING_DOMAIN_LEUCINE_RICH_REPEAT_CONTAINING_RECEPTOR_NLR_SIGNALING_PATHWAYS',
#        'REACTOME_RND2_GTPASE_CYCLE'],
#       dtype='str', name='pathway')
# Index(['REACTOME_INTEGRIN_SIGNALING', 'REACTOME_SIGNALING_BY_TGFBR3',
#        'REACTOME_GPVI_MEDIATED_ACTIVATION_CASCADE',
#        'REACTOME_CD209_DC_SIGN_SIGNALING',
#        'REACTOME_CONSTITUTIVE_SIGNALING_BY_ABERRANT_PI3K_IN_CANCER',
#        'REACTOME_SIGNALING_BY_TGFB_FAMILY_MEMBERS',
#        'REACTOME_SIGNALING_BY_SCF_KIT', 'REACTOME_CO_STIMULATION_BY_CD28'],
#       dtype='str', name='pathway')
# Index(['REACTOME_SIGNALING_BY_TGFBR3', 'REACTOME_ATTENUATION_PHASE',
#        'REACTOME_MITF_M_DEPENDENT_GENE_EXPRESSION',
#        'REACTOME_HSF1_DEPENDENT_TRANSACTIVATION',
#        'REACTOME_IMMUNOREGULATORY_INTERACTIONS_BETWEEN_A_LYMPHOID_AND_A_NON_LYMPHOID_CELL',
#        'REACTOME_RND3_GTPASE_CYCLE',
#        'REACTOME_GPVI_MEDIATED_ACTIVATION_CASCADE', 'REACTOME_DAP12_SIGNALING',
#        'REACTOME_SENSORY_PROCESSING_OF_SOUND_BY_OUTER_HAIR_CELLS_OF_THE_COCHLEA',
#        'REACTOME_CD209_DC_SIGN_SIGNALING',
#        'REACTOME_FC_EPSILON_RECEPTOR_FCERI_SIGNALING',
#        'REACTOME_RHO_GTPASES_ACTIVATE_PKNS', 'REACTOME_DAP12_INTERACTIONS',
#        'REACTOME_SIGNALING_BY_THE_B_CELL_RECEPTOR_BCR',
#        'REACTOME_FCERI_MEDIATED_CA_2_MOBILIZATION',
#        'REACTOME_ANTIGEN_ACTIVATES_B_CELL_RECEPTOR_BCR_LEADING_TO_GENERATION_OF_SECOND_MESSENGERS',
#        'REACTOME_LEISHMANIA_INFECTION',
#        'REACTOME_CELL_SURFACE_INTERACTIONS_AT_THE_VASCULAR_WALL',
#        'REACTOME_FCERI_MEDIATED_MAPK_ACTIVATION',
#        'REACTOME_SENSORY_PROCESSING_OF_SOUND',
#        'REACTOME_SMOOTH_MUSCLE_CONTRACTION',
#        'REACTOME_FCGAMMA_RECEPTOR_FCGR_DEPENDENT_PHAGOCYTOSIS',
#        'REACTOME_REGULATION_OF_CDH1_GENE_TRANSCRIPTION',
#        'REACTOME_FCGR_ACTIVATION',
#        'REACTOME_RECRUITMENT_OF_MITOTIC_CENTROSOME_PROTEINS_AND_COMPLEXES',
#        'REACTOME_REGULATION_OF_MECP2_EXPRESSION_AND_ACTIVITY',
#        'REACTOME_PARASITE_INFECTION',
#        'REACTOME_EPH_EPHRIN_MEDIATED_REPULSION_OF_CELLS',
#        'REACTOME_FCERI_MEDIATED_NF_KB_ACTIVATION',
#        'REACTOME_GLUCAGON_SIGNALING_IN_METABOLIC_REGULATION',
#        'REACTOME_HSF1_ACTIVATION',
#        'REACTOME_ROLE_OF_LAT2_NTAL_LAB_ON_CALCIUM_MOBILIZATION',
#        'REACTOME_RHOD_GTPASE_CYCLE',
#        'REACTOME_ANTI_INFLAMMATORY_RESPONSE_FAVOURING_LEISHMANIA_PARASITE_INFECTION',
#        'REACTOME_ADORA2B_MEDIATED_ANTI_INFLAMMATORY_CYTOKINES_PRODUCTION',
#        'REACTOME_TRIGLYCERIDE_CATABOLISM',
#        'REACTOME_REGULATION_OF_PLK1_ACTIVITY_AT_G2_M_TRANSITION',
#        'REACTOME_FORMATION_OF_THE_DYSTROPHIN_GLYCOPROTEIN_COMPLEX_DGC',
#        'REACTOME_OXIDATIVE_STRESS_INDUCED_SENESCENCE',
#        'REACTOME_LATE_ENDOSOMAL_MICROAUTOPHAGY',
#        'REACTOME_MITF_M_REGULATED_MELANOCYTE_DEVELOPMENT',
#        'REACTOME_CRISTAE_FORMATION', 'REACTOME_AURKA_ACTIVATION_BY_TPX2',
#        'REACTOME_PLATELET_ACTIVATION_SIGNALING_AND_AGGREGATION',
#        'REACTOME_DNA_DAMAGE_TELOMERE_STRESS_INDUCED_SENESCENCE',
#        'REACTOME_NERVOUS_SYSTEM_DEVELOPMENT'],
#       dtype='str', name='pathway')
# Index(['REACTOME_CO_INHIBITION_BY_CTLA4'], dtype='str', name='pathway')

# %%
pc1_comparison.head(30)
# Out:
#                                                pathway  mean_abs_r_untrained  \
# 465                REACTOME_G2_M_DNA_DAMAGE_CHECKPOINT              0.283471
# 373  REACTOME_INITIATION_OF_NUCLEAR_ENVELOPE_NE_REF...              0.310512
# 738  REACTOME_ADP_SIGNALLING_THROUGH_P2Y_PURINOCEPT...              0.175512
# 352                 REACTOME_APOPTOTIC_EXECUTION_PHASE              0.316883
# 86           REACTOME_MITF_M_DEPENDENT_GENE_EXPRESSION              0.419737
# 4                         REACTOME_SIGNALING_BY_TGFBR3              0.516872
# 434                     REACTOME_BIOLOGICAL_OXIDATIONS              0.290585
# 591                    REACTOME_ESR_MEDIATED_SIGNALING              0.250445
# 526  REACTOME_DEFECTIVE_INTRINSIC_PATHWAY_FOR_APOPT...              0.266057
# 351    REACTOME_PHASE_I_FUNCTIONALIZATION_OF_COMPOUNDS              0.317378
# 662                      REACTOME_SIGNAL_AMPLIFICATION              0.225452
# 393            REACTOME_SIGNALING_BY_NUCLEAR_RECEPTORS              0.304756
# 597                REACTOME_INSULIN_RECEPTOR_RECYCLING              0.248918
# 701     REACTOME_TRANSFERRIN_ENDOCYTOSIS_AND_RECYCLING              0.202537
# 388                REACTOME_GABA_B_RECEPTOR_ACTIVATION              0.306959
# 221   REACTOME_MITF_M_REGULATED_MELANOCYTE_DEVELOPMENT              0.358498
# 193  REACTOME_GLUCAGON_SIGNALING_IN_METABOLIC_REGUL...              0.370427
# 477                 REACTOME_FLT3_SIGNALING_IN_DISEASE              0.280610
# 291          REACTOME_EXTRA_NUCLEAR_ESTROGEN_SIGNALING              0.334710
# 448                                 REACTOME_APOPTOSIS              0.288093
# 761  REACTOME_PROTEIN_PROTEIN_INTERACTIONS_AT_SYNAPSES              0.159197
# 257  REACTOME_VASOPRESSIN_REGULATES_RENAL_WATER_HOM...              0.347991
# 258              REACTOME_AQUAPORIN_MEDIATED_TRANSPORT              0.347991
# 786            REACTOME_MAPK_FAMILY_SIGNALING_CASCADES              0.104670
# 370                                   REACTOME_MEIOSIS              0.312372
# 512  REACTOME_COOPERATION_OF_PDCL_PHLP1_AND_TRIC_CC...              0.269288
# 635                         REACTOME_RAC3_GTPASE_CYCLE              0.237802
# 196  REACTOME_DNA_DAMAGE_TELOMERE_STRESS_INDUCED_SE...              0.368954
# 114                      REACTOME_LEISHMANIA_INFECTION              0.402182
# 579  REACTOME_RUNX1_INTERACTS_WITH_CO_FACTORS_WHOSE...              0.253715
#
#      mean_abs_r_trained  delta_mean_abs_r
# 465            0.407525          0.124054
# 373            0.431698          0.121186
# 738            0.294448          0.118936
# 352            0.433437          0.116554
# 86             0.535854          0.116117
# 4              0.632512          0.115639
# 434            0.404642          0.114057
# 591            0.359579          0.109134
# 526            0.374302          0.108245
# 351            0.425328          0.107950
# 662            0.332389          0.106937
# 393            0.409810          0.105054
# 597            0.351217          0.102299
# 701            0.302780          0.100243
# 388            0.407166          0.100207
# 221            0.457735          0.099236
# 193            0.466777          0.096350
# 477            0.375518          0.094908
# 291            0.429548          0.094838
# 448            0.380538          0.092445
# 761            0.250846          0.091648
# 257            0.438471          0.090479
# 258            0.438471          0.090479
# 786            0.193797          0.089127
# 370            0.398713          0.086341
# 512            0.353807          0.084519
# 635            0.321189          0.083388
# 196            0.452218          0.083264
# 114            0.485239          0.083057
# 579            0.336637          0.082922

# %%
a = ['REACTOME_ELASTIC_FIBRE_FORMATION', 'REACTOME_NON_INTEGRIN_MEMBRANE_ECM_INTERACTIONS','REACTOME_COLLAGEN_FORMATION','REACTOME_COLLAGEN_DEGRADATION','REACTOME_DEGRADATION_OF_THE_EXTRACELLULAR_MATRIX','REACTOME_INTEGRIN_CELL_SURFACE_INTERACTIONS',' REACTOME_EXTRACELLULAR_MATRIX_ORGANIZATION']
print(pc1_comparison[pc1_comparison['pathway'].isin(a)])
# Out:
#                                               pathway  mean_abs_r_untrained  \
# 752                     REACTOME_COLLAGEN_DEGRADATION              0.166571
# 601  REACTOME_DEGRADATION_OF_THE_EXTRACELLULAR_MATRIX              0.246669
# 268                       REACTOME_COLLAGEN_FORMATION              0.344802
# 455       REACTOME_INTEGRIN_CELL_SURFACE_INTERACTIONS              0.286330
# 24                   REACTOME_ELASTIC_FIBRE_FORMATION              0.477283
# 108   REACTOME_NON_INTEGRIN_MEMBRANE_ECM_INTERACTIONS              0.404292
#
#      mean_abs_r_trained  delta_mean_abs_r
# 752            0.165349         -0.001222
# 601            0.225333         -0.021336
# 268            0.299198         -0.045604
# 455            0.225904         -0.060426
# 24             0.399454         -0.077829
# 108            0.288938         -0.115354

# %%
matching_pathways = (set(top_pearson_PC1_trained_index)
    | set(top_pearson_PC2_trained_index)).intersection((set(top_pearson_PC1_index)
    | set(top_pearson_PC2_index)))
trained_unique = (set(top_pearson_PC1_trained_index)
    | set(top_pearson_PC2_trained_index)).difference((set(top_pearson_PC1_index)
    | set(top_pearson_PC2_index)))
untrained_unique =  (set(top_pearson_PC1_index)
    | set(top_pearson_PC2_index)).difference((set(top_pearson_PC1_trained_index)
    | set(top_pearson_PC2_trained_index)))

# %%
print(f'matching pathways = {matching_pathways}')
print(f'trained unique = {trained_unique}')
print(f'untrained unique = {untrained_unique}')
# Out:
# matching pathways = {'REACTOME_DAP12_SIGNALING', 'REACTOME_IMMUNOREGULATORY_INTERACTIONS_BETWEEN_A_LYMPHOID_AND_A_NON_LYMPHOID_CELL', 'REACTOME_ATTENUATION_PHASE', 'REACTOME_FC_EPSILON_RECEPTOR_FCERI_SIGNALING', 'REACTOME_SIGNALING_BY_TGFBR3', 'REACTOME_SIGNALING_BY_THE_B_CELL_RECEPTOR_BCR', 'REACTOME_RHO_GTPASES_ACTIVATE_PKNS', 'REACTOME_SMOOTH_MUSCLE_CONTRACTION', 'REACTOME_RND3_GTPASE_CYCLE', 'REACTOME_CRISTAE_FORMATION', 'REACTOME_RECRUITMENT_OF_MITOTIC_CENTROSOME_PROTEINS_AND_COMPLEXES', 'REACTOME_REGULATION_OF_CDH1_GENE_TRANSCRIPTION', 'REACTOME_AURKA_ACTIVATION_BY_TPX2', 'REACTOME_CD209_DC_SIGN_SIGNALING', 'REACTOME_DAP12_INTERACTIONS', 'REACTOME_FORMATION_OF_THE_DYSTROPHIN_GLYCOPROTEIN_COMPLEX_DGC', 'REACTOME_CELL_SURFACE_INTERACTIONS_AT_THE_VASCULAR_WALL', 'REACTOME_EPH_EPHRIN_MEDIATED_REPULSION_OF_CELLS', 'REACTOME_REGULATION_OF_PLK1_ACTIVITY_AT_G2_M_TRANSITION', 'REACTOME_GPVI_MEDIATED_ACTIVATION_CASCADE', 'REACTOME_FCERI_MEDIATED_CA_2_MOBILIZATION', 'REACTOME_ANTIGEN_ACTIVATES_B_CELL_RECEPTOR_BCR_LEADING_TO_GENERATION_OF_SECOND_MESSENGERS', 'REACTOME_OXIDATIVE_STRESS_INDUCED_SENESCENCE', 'REACTOME_HSF1_DEPENDENT_TRANSACTIVATION', 'REACTOME_NERVOUS_SYSTEM_DEVELOPMENT'}
# trained unique = {'REACTOME_ROLE_OF_LAT2_NTAL_LAB_ON_CALCIUM_MOBILIZATION', 'REACTOME_SENSORY_PROCESSING_OF_SOUND', 'REACTOME_PLATELET_ACTIVATION_SIGNALING_AND_AGGREGATION', 'REACTOME_FCERI_MEDIATED_MAPK_ACTIVATION', 'REACTOME_GLUCAGON_SIGNALING_IN_METABOLIC_REGULATION', 'REACTOME_TRIGLYCERIDE_CATABOLISM', 'REACTOME_FCGR_ACTIVATION', 'REACTOME_SENSORY_PROCESSING_OF_SOUND_BY_OUTER_HAIR_CELLS_OF_THE_COCHLEA', 'REACTOME_DNA_DAMAGE_TELOMERE_STRESS_INDUCED_SENESCENCE', 'REACTOME_PARASITE_INFECTION', 'REACTOME_RHOD_GTPASE_CYCLE', 'REACTOME_MITF_M_REGULATED_MELANOCYTE_DEVELOPMENT', 'REACTOME_HSF1_ACTIVATION', 'REACTOME_LATE_ENDOSOMAL_MICROAUTOPHAGY', 'REACTOME_MITF_M_DEPENDENT_GENE_EXPRESSION', 'REACTOME_CO_INHIBITION_BY_CTLA4', 'REACTOME_REGULATION_OF_MECP2_EXPRESSION_AND_ACTIVITY', 'REACTOME_ANTI_INFLAMMATORY_RESPONSE_FAVOURING_LEISHMANIA_PARASITE_INFECTION', 'REACTOME_LEISHMANIA_INFECTION', 'REACTOME_ADORA2B_MEDIATED_ANTI_INFLAMMATORY_CYTOKINES_PRODUCTION', 'REACTOME_FCERI_MEDIATED_NF_KB_ACTIVATION', 'REACTOME_FCGAMMA_RECEPTOR_FCGR_DEPENDENT_PHAGOCYTOSIS'}
# untrained unique = {'REACTOME_RHOQ_GTPASE_CYCLE', 'REACTOME_SIGNALING_BY_SCF_KIT', 'REACTOME_NEUTROPHIL_DEGRANULATION', 'REACTOME_CO_STIMULATION_BY_CD28', 'REACTOME_NUCLEOTIDE_SALVAGE', 'REACTOME_RESPIRATORY_SYNCYTIAL_VIRUS_RSV_ATTACHMENT_AND_ENTRY', 'REACTOME_GLYCOSAMINOGLYCAN_PROTEIN_LINKAGE_REGION_BIOSYNTHESIS', 'REACTOME_ELASTIC_FIBRE_FORMATION', 'REACTOME_RND2_GTPASE_CYCLE', 'REACTOME_PEPTIDE_LIGAND_BINDING_RECEPTORS', 'REACTOME_SIGNALING_BY_TGFB_FAMILY_MEMBERS', 'REACTOME_RESPIRATORY_SYNCYTIAL_VIRUS_INFECTION_PATHWAY', 'REACTOME_DARPP_32_EVENTS', 'REACTOME_EARLY_SARS_COV_2_INFECTION_EVENTS', 'REACTOME_BACTERIAL_INFECTION_PATHWAYS', 'REACTOME_NUCLEOTIDE_BINDING_DOMAIN_LEUCINE_RICH_REPEAT_CONTAINING_RECEPTOR_NLR_SIGNALING_PATHWAYS', 'REACTOME_CONSTITUTIVE_SIGNALING_BY_ABERRANT_PI3K_IN_CANCER', 'REACTOME_SIGNALING_BY_INTERLEUKINS', 'REACTOME_INTEGRIN_SIGNALING', 'REACTOME_ORGANELLE_BIOGENESIS_AND_MAINTENANCE', 'REACTOME_METABOLIC_DISORDERS_OF_BIOLOGICAL_OXIDATION_ENZYMES', 'REACTOME_INTERLEUKIN_4_AND_INTERLEUKIN_13_SIGNALING', 'REACTOME_CLASS_A_1_RHODOPSIN_LIKE_RECEPTORS', 'REACTOME_ANCHORING_OF_THE_BASAL_BODY_TO_THE_PLASMA_MEMBRANE', 'REACTOME_NOD1_2_SIGNALING_PATHWAY'}

# %%
results_comparison ={}
pathways = (set(top_pearson_PC1_trained_index)
    | set(top_pearson_PC2_trained_index))
print(pathways)
for pathway in pathways:
    results_comparison[pathway] = {
        "PC1": top_pearson_PC1.loc[pathway, "mean_abs_r"],
        "PC2": top_pearson_PC2.loc[pathway, "mean_abs_r"],
        "PC1_trained": top_pearson_PC1_trained.loc[pathway, "mean_abs_r"],
        "PC2_trained": top_pearson_PC2_trained.loc[pathway, "mean_abs_r"],
    }

results_comparison_df = pd.DataFrame.from_dict(
    results_comparison,
    orient="index"
)
results_comparison_df.head(10)
# Out:
# {'REACTOME_ROLE_OF_LAT2_NTAL_LAB_ON_CALCIUM_MOBILIZATION', 'REACTOME_DAP12_SIGNALING', 'REACTOME_SENSORY_PROCESSING_OF_SOUND', 'REACTOME_PLATELET_ACTIVATION_SIGNALING_AND_AGGREGATION', 'REACTOME_IMMUNOREGULATORY_INTERACTIONS_BETWEEN_A_LYMPHOID_AND_A_NON_LYMPHOID_CELL', 'REACTOME_NERVOUS_SYSTEM_DEVELOPMENT', 'REACTOME_FCERI_MEDIATED_MAPK_ACTIVATION', 'REACTOME_GLUCAGON_SIGNALING_IN_METABOLIC_REGULATION', 'REACTOME_ATTENUATION_PHASE', 'REACTOME_TRIGLYCERIDE_CATABOLISM', 'REACTOME_FCGR_ACTIVATION', 'REACTOME_SENSORY_PROCESSING_OF_SOUND_BY_OUTER_HAIR_CELLS_OF_THE_COCHLEA', 'REACTOME_FC_EPSILON_RECEPTOR_FCERI_SIGNALING', 'REACTOME_DNA_DAMAGE_TELOMERE_STRESS_INDUCED_SENESCENCE', 'REACTOME_PARASITE_INFECTION', 'REACTOME_SIGNALING_BY_TGFBR3', 'REACTOME_RHOD_GTPASE_CYCLE', 'REACTOME_RHO_GTPASES_ACTIVATE_PKNS', 'REACTOME_SMOOTH_MUSCLE_CONTRACTION', 'REACTOME_RND3_GTPASE_CYCLE', 'REACTOME_CRISTAE_FORMATION', 'REACTOME_MITF_M_REGULATED_MELANOCYTE_DEVELOPMENT', 'REACTOME_RECRUITMENT_OF_MITOTIC_CENTROSOME_PROTEINS_AND_COMPLEXES', 'REACTOME_OXIDATIVE_STRESS_INDUCED_SENESCENCE', 'REACTOME_REGULATION_OF_CDH1_GENE_TRANSCRIPTION', 'REACTOME_HSF1_ACTIVATION', 'REACTOME_AURKA_ACTIVATION_BY_TPX2', 'REACTOME_CD209_DC_SIGN_SIGNALING', 'REACTOME_LATE_ENDOSOMAL_MICROAUTOPHAGY', 'REACTOME_DAP12_INTERACTIONS', 'REACTOME_MITF_M_DEPENDENT_GENE_EXPRESSION', 'REACTOME_CO_INHIBITION_BY_CTLA4', 'REACTOME_FORMATION_OF_THE_DYSTROPHIN_GLYCOPROTEIN_COMPLEX_DGC', 'REACTOME_CELL_SURFACE_INTERACTIONS_AT_THE_VASCULAR_WALL', 'REACTOME_REGULATION_OF_MECP2_EXPRESSION_AND_ACTIVITY', 'REACTOME_REGULATION_OF_PLK1_ACTIVITY_AT_G2_M_TRANSITION', 'REACTOME_GPVI_MEDIATED_ACTIVATION_CASCADE', 'REACTOME_FCERI_MEDIATED_CA_2_MOBILIZATION', 'REACTOME_ANTI_INFLAMMATORY_RESPONSE_FAVOURING_LEISHMANIA_PARASITE_INFECTION', 'REACTOME_LEISHMANIA_INFECTION', 'REACTOME_ANTIGEN_ACTIVATES_B_CELL_RECEPTOR_BCR_LEADING_TO_GENERATION_OF_SECOND_MESSENGERS', 'REACTOME_ADORA2B_MEDIATED_ANTI_INFLAMMATORY_CYTOKINES_PRODUCTION', 'REACTOME_FCERI_MEDIATED_NF_KB_ACTIVATION', 'REACTOME_FCGAMMA_RECEPTOR_FCGR_DEPENDENT_PHAGOCYTOSIS', 'REACTOME_EPH_EPHRIN_MEDIATED_REPULSION_OF_CELLS', 'REACTOME_HSF1_DEPENDENT_TRANSACTIVATION', 'REACTOME_SIGNALING_BY_THE_B_CELL_RECEPTOR_BCR'}
#                                                          PC1       PC2  \
# REACTOME_ROLE_OF_LAT2_NTAL_LAB_ON_CALCIUM_MOBIL...  0.428351  0.326214
# REACTOME_DAP12_SIGNALING                            0.508393  0.404232
# REACTOME_SENSORY_PROCESSING_OF_SOUND                0.410516  0.375483
# REACTOME_PLATELET_ACTIVATION_SIGNALING_AND_AGGR...  0.403282  0.435076
# REACTOME_IMMUNOREGULATORY_INTERACTIONS_BETWEEN_...  0.498878  0.362968
# REACTOME_NERVOUS_SYSTEM_DEVELOPMENT                 0.479443  0.328449
# REACTOME_FCERI_MEDIATED_MAPK_ACTIVATION             0.438948  0.338383
# REACTOME_GLUCAGON_SIGNALING_IN_METABOLIC_REGULA...  0.370427  0.333926
# REACTOME_ATTENUATION_PHASE                          0.578437  0.427635
# REACTOME_TRIGLYCERIDE_CATABOLISM                    0.383528  0.436866
#
#                                                     PC1_trained  PC2_trained
# REACTOME_ROLE_OF_LAT2_NTAL_LAB_ON_CALCIUM_MOBIL...     0.463727     0.191579
# REACTOME_DAP12_SIGNALING                               0.510209     0.367301
# REACTOME_SENSORY_PROCESSING_OF_SOUND                   0.478211     0.205611
# REACTOME_PLATELET_ACTIVATION_SIGNALING_AND_AGGR...     0.452998     0.231549
# REACTOME_IMMUNOREGULATORY_INTERACTIONS_BETWEEN_...     0.523617     0.224908
# REACTOME_NERVOUS_SYSTEM_DEVELOPMENT                    0.450112     0.169107
# REACTOME_FCERI_MEDIATED_MAPK_ACTIVATION                0.480395     0.189415
# REACTOME_GLUCAGON_SIGNALING_IN_METABOLIC_REGULA...     0.466777     0.265633
# REACTOME_ATTENUATION_PHASE                             0.557028     0.169052
# REACTOME_TRIGLYCERIDE_CATABOLISM                       0.460818     0.191893

# %%
plot_data_PC1 = cross_plasma_to_tissue[
    (cross_plasma_to_tissue["PC"] == "PC1") &
    (cross_plasma_to_tissue["pathway"].isin(top_pearson_PC1_index))
].copy()

plot_data_PC1["abs_pearson_r"] = plot_data_PC1["pearson_r"].abs()

plot_df_PC1 = plot_data_PC1.pivot(
    index="pathway",
    columns="fold",
    values="abs_pearson_r"
)
plot_df_PC1
# Out:
# fold                                                       0         1  \
# pathway
# REACTOME_ATTENUATION_PHASE                          0.746979  0.319138
# REACTOME_CD209_DC_SIGN_SIGNALING                    0.498326  0.641797
# REACTOME_CONSTITUTIVE_SIGNALING_BY_ABERRANT_PI3...  0.560357  0.402306
# REACTOME_DAP12_INTERACTIONS                         0.917172  0.264058
# REACTOME_DAP12_SIGNALING                            0.907422  0.238426
# REACTOME_EPH_EPHRIN_MEDIATED_REPULSION_OF_CELLS     0.353644  0.549018
# REACTOME_GPVI_MEDIATED_ACTIVATION_CASCADE           0.828017  0.155218
# REACTOME_INTEGRIN_SIGNALING                         0.762378  0.398732
# REACTOME_MITF_M_DEPENDENT_GENE_EXPRESSION           0.510874  0.393415
# REACTOME_SIGNALING_BY_TGFBR3                        0.550058  0.677755
#
# fold                                                       2         3  \
# pathway
# REACTOME_ATTENUATION_PHASE                          0.072405  0.734105
# REACTOME_CD209_DC_SIGN_SIGNALING                    0.428410  0.758737
# REACTOME_CONSTITUTIVE_SIGNALING_BY_ABERRANT_PI3...  0.627111  0.296790
# REACTOME_DAP12_INTERACTIONS                         0.390590  0.013360
# REACTOME_DAP12_SIGNALING                            0.444290  0.103499
# REACTOME_EPH_EPHRIN_MEDIATED_REPULSION_OF_CELLS     0.366788  0.670896
# REACTOME_GPVI_MEDIATED_ACTIVATION_CASCADE           0.633713  0.365574
# REACTOME_INTEGRIN_SIGNALING                         0.631694  0.348427
# REACTOME_MITF_M_DEPENDENT_GENE_EXPRESSION           0.387248  0.405885
# REACTOME_SIGNALING_BY_TGFBR3                        0.496029  0.511251
#
# fold                                                       4
# pathway
# REACTOME_ATTENUATION_PHASE                          0.673897
# REACTOME_CD209_DC_SIGN_SIGNALING                    0.265868
# REACTOME_CONSTITUTIVE_SIGNALING_BY_ABERRANT_PI3...  0.550889
# REACTOME_DAP12_INTERACTIONS                         0.772494
# REACTOME_DAP12_SIGNALING                            0.780106
# REACTOME_EPH_EPHRIN_MEDIATED_REPULSION_OF_CELLS     0.467110
# REACTOME_GPVI_MEDIATED_ACTIVATION_CASCADE           0.774868
# REACTOME_INTEGRIN_SIGNALING                         0.274293
# REACTOME_MITF_M_DEPENDENT_GENE_EXPRESSION           0.691689
# REACTOME_SIGNALING_BY_TGFBR3                        0.758545

# %%
import matplotlib.pyplot as plt
import numpy as np

for pathway in top_pearson_PC1_index:

    pathway_df = cross_plasma_to_tissue[
        (cross_plasma_to_tissue["PC"] == "PC1") &
        (cross_plasma_to_tissue["pathway"] == pathway)
    ]

    fig, axes = plt.subplots(
        1, 5,
        figsize=(18, 3.5),
        sharex=False,
        sharey=False
    )

    for ax, (_, row) in zip(axes, pathway_df.iterrows()):

        fold = row["fold"]

        # Get the actual patient-level data for this fold
        fold_data = plasma_pc_tissue_pathways[
            plasma_pc_tissue_pathways["fold"] == fold
        ]

        x = fold_data["PC1"]
        y = fold_data[pathway]

        ax.scatter(x, y, alpha=0.7)

        # Regression line
        if len(x) >= 3:
            z = np.polyfit(x, y, 1)
            x_line = np.linspace(x.min(), x.max(), 100)
            y_line = z[0] * x_line + z[1]
            ax.plot(x_line, y_line)

        ax.set_title(
            f"Fold {int(fold)}\n"
            f"r = {row['pearson_r']:.2f}"
        )

        ax.set_xlabel("Plasma PC1")

    axes[0].set_ylabel("Tissue pathway score")
    abs_r = pathway_df.agg(pearson_mean_abs_r=("pearson_r", lambda x: x.abs().mean()))

    fig.suptitle(
        f'{pathway.replace("REACTOME_", "")} {(abs_r.values)}',
        fontsize=13
    )

    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

for pathway in top_pearson_PC2_index:

    pathway_df = cross_plasma_to_tissue[
        (cross_plasma_to_tissue["PC"] == "PC2") &
        (cross_plasma_to_tissue["pathway"] == pathway)
    ]

    fig, axes = plt.subplots(
        1, 5,
        figsize=(18, 3.5),
        sharex=False,
        sharey=False
    )

    for ax, (_, row) in zip(axes, pathway_df.iterrows()):

        fold = row["fold"]

        # Get the actual patient-level data for this fold
        fold_data = plasma_pc_tissue_pathways[
            plasma_pc_tissue_pathways["fold"] == fold
        ]

        x = fold_data["PC2"]
        y = fold_data[pathway]

        ax.scatter(x, y, alpha=0.7)

        # Regression line
        if len(x) >= 3:
            z = np.polyfit(x, y, 1)
            x_line = np.linspace(x.min(), x.max(), 100)
            y_line = z[0] * x_line + z[1]
            ax.plot(x_line, y_line)

        ax.set_title(
            f"Fold {int(fold)}\n"
            f"r = {row['pearson_r']:.2f}"
        )

        ax.set_xlabel("Plasma PC2")

    axes[0].set_ylabel("Tissue pathway score")
    abs_r = pathway_df.agg(pearson_mean_abs_r=("pearson_r", lambda x: x.abs().mean()))

    fig.suptitle(
        f'{pathway.replace("REACTOME_", "")} {(abs_r.values)}',
        fontsize=13
    )

    plt.tight_layout()
    plt.show()

# %%
print(top_pearson)
# Out:
# Index(['REACTOME_MITF_M_DEPENDENT_GENE_EXPRESSION',
#        'REACTOME_RND3_GTPASE_CYCLE', 'REACTOME_SMOOTH_MUSCLE_CONTRACTION',
#        'REACTOME_SIGNALING_BY_TGFBR3', 'REACTOME_DAP12_INTERACTIONS',
#        'REACTOME_SENSORY_PROCESSING_OF_SOUND_BY_OUTER_HAIR_CELLS_OF_THE_COCHLEA',
#        'REACTOME_RHO_GTPASES_ACTIVATE_PKNS',
#        'REACTOME_GPVI_MEDIATED_ACTIVATION_CASCADE', 'REACTOME_DAP12_SIGNALING',
#        'REACTOME_HSF1_DEPENDENT_TRANSACTIVATION'],
#       dtype='str', name='pathway')

# %%
print(type(top_pearson))
print(type(pathway_correlations))
print(pathway_correlations.head())
# Out:
# <class 'pandas.Index'>
# <class 'pandas.DataFrame'>
#                                              pathway   n  pearson_r  \
# 0  REACTOME_DEVELOPMENTAL_CELL_LINEAGES_OF_THE_EX...  52  -0.107435
# 1            REACTOME_FORMATION_OF_PARAXIAL_MESODERM  52  -0.040573
# 2                       REACTOME_SARS_COV_INFECTIONS  52  -0.128560
# 3          REACTOME_INITIAL_TRIGGERING_OF_COMPLEMENT  52   0.167309
# 4       REACTOME_TRANSCRIPTIONAL_REGULATION_BY_RUNX2  52  -0.008501
#
#    pearson_p  spearman_r  spearman_p
# 0   0.448398   -0.040724    0.774384
# 1   0.775198   -0.108683    0.443113
# 2   0.363720   -0.172885    0.220335
# 3   0.235806    0.201400    0.152221
# 4   0.952303   -0.098267    0.488267

# %%
print(len(plot_data['pathway']))
# Out:
# 50

# %%
pathway_comp = (
    cross_plasma_to_tissue[
        (cross_plasma_to_tissue["PC"] == "PC2") &
        (cross_plasma_to_tissue["pathway"].isin(top_pearson))
    ]
    .groupby("pathway")
    .agg(
        pc_pathway_abs_r=("pearson_r", lambda x: x.abs().mean())
    )
    .reset_index()
)

pathway_correlations_1 = pathway_correlations[
    pathway_correlations["pathway"].isin(top_pearson)
][["pathway", "pearson_r"]]

pathway_comp = pathway_comp.merge(
    pathway_correlations_1,
    on="pathway",
    how="left"
)

pathway_comp = pathway_comp.rename(columns={
    "pc_pathway_abs_r": "PC2 plasma → tissue pathway |r|",
    "pearson_r": "Plasma pathway ↔ tissue pathway r"
})

print(pathway_comp.head(10))
# Out:
#                                              pathway  \
# 0                         REACTOME_ATTENUATION_PHASE
# 1                   REACTOME_CD209_DC_SIGN_SIGNALING
# 2  REACTOME_CONSTITUTIVE_SIGNALING_BY_ABERRANT_PI...
# 3    REACTOME_EPH_EPHRIN_MEDIATED_REPULSION_OF_CELLS
# 4          REACTOME_GPVI_MEDIATED_ACTIVATION_CASCADE
# 5                        REACTOME_INTEGRIN_SIGNALING
# 6          REACTOME_MITF_M_DEPENDENT_GENE_EXPRESSION
# 7                         REACTOME_RND3_GTPASE_CYCLE
# 8                       REACTOME_SIGNALING_BY_TGFBR3
# 9  REACTOME_SYNTHESIS_OF_PIPS_AT_THE_PLASMA_MEMBRANE
#
#    PC2 plasma → tissue pathway |r|  Plasma pathway ↔ tissue pathway r
# 0                         0.464834                                NaN
# 1                         0.499300                                NaN
# 2                         0.457290                                NaN
# 3                         0.460089                                NaN
# 4                         0.537829                                NaN
# 5                         0.495519                          -0.128994
# 6                         0.472715                          -0.228976
# 7                         0.462946                                NaN
# 8                         0.574773                                NaN
# 9                         0.457041                                NaN

# %%
pathway_comp.head(10)
# Out:
#                                              pathway  \
# 0                         REACTOME_ATTENUATION_PHASE
# 1                   REACTOME_CD209_DC_SIGN_SIGNALING
# 2  REACTOME_CONSTITUTIVE_SIGNALING_BY_ABERRANT_PI...
# 3    REACTOME_EPH_EPHRIN_MEDIATED_REPULSION_OF_CELLS
# 4          REACTOME_GPVI_MEDIATED_ACTIVATION_CASCADE
# 5                        REACTOME_INTEGRIN_SIGNALING
# 6          REACTOME_MITF_M_DEPENDENT_GENE_EXPRESSION
# 7                         REACTOME_RND3_GTPASE_CYCLE
# 8                       REACTOME_SIGNALING_BY_TGFBR3
# 9  REACTOME_SYNTHESIS_OF_PIPS_AT_THE_PLASMA_MEMBRANE
#
#    PC2 plasma → tissue pathway |r|  Plasma pathway ↔ tissue pathway r
# 0                         0.464834                                NaN
# 1                         0.499300                                NaN
# 2                         0.457290                                NaN
# 3                         0.460089                                NaN
# 4                         0.537829                                NaN
# 5                         0.495519                          -0.128994
# 6                         0.472715                          -0.228976
# 7                         0.462946                                NaN
# 8                         0.574773                                NaN
# 9                         0.457041                                NaN

# %%
plt.figure(figsize=(8, 6))

plt.imshow(
    plot_df_PC2,
    aspect="auto"
)

plt.xticks(
    range(len(plot_df_PC2.columns)),
    [f"Fold {x}" for x in plot_df_PC2.columns]
)

plt.yticks(
    range(len(plot_df_PC2.index)),
    [
        x.replace("REACTOME_", "")
        for x in plot_df_PC2.index
    ]
)

plt.colorbar(label="Spearman r")

plt.xlabel("Fold")
plt.ylabel("Tissue pathway")
plt.title("Plasma PC2 vs tissue pathway correlations")

plt.tight_layout()
plt.show()

# %%
summary_plasma_to_tissue[
    (summary_plasma_to_tissue["PC"] == "PC2") &
    (summary_plasma_to_tissue["n_folds"] == 5)
].sort_values(['spearman_mean_abs_r'],
    ascending=False
).head(30)
# Out:
#        PC                                            pathway  \
# 1468  PC2                       REACTOME_SIGNALING_BY_TGFBR3
# 823   PC2                   REACTOME_ARACHIDONATE_METABOLISM
# 855   PC2                   REACTOME_CD209_DC_SIGN_SIGNALING
# 1024  PC2  REACTOME_FORMATION_OF_THE_DYSTROPHIN_GLYCOPROT...
# 861   PC2      REACTOME_CELLULAR_RESPONSE_TO_CHEMICAL_STRESS
# 917   PC2                        REACTOME_DAP12_INTERACTIONS
# 1170  PC2   REACTOME_MITF_M_REGULATED_MELANOCYTE_DEVELOPMENT
# 1169  PC2          REACTOME_MITF_M_DEPENDENT_GENE_EXPRESSION
# 1104  PC2                        REACTOME_INTEGRIN_SIGNALING
# 1075  PC2  REACTOME_HEPARAN_SULFATE_HEPARIN_HS_GAG_METABO...
# 1374  PC2                 REACTOME_RHO_GTPASES_ACTIVATE_PKNS
# 1480  PC2                 REACTOME_SMOOTH_MUSCLE_CONTRACTION
# 1047  PC2              REACTOME_GLYCOSAMINOGLYCAN_METABOLISM
# 1392  PC2                         REACTOME_RND3_GTPASE_CYCLE
# 918   PC2                           REACTOME_DAP12_SIGNALING
# 1210  PC2                REACTOME_NERVOUS_SYSTEM_DEVELOPMENT
# 915   PC2              REACTOME_C_TYPE_LECTIN_RECEPTORS_CLRS
# 1138  PC2             REACTOME_LATE_ENDOSOMAL_MICROAUTOPHAGY
# 1308  PC2     REACTOME_REGULATION_OF_CDH1_GENE_TRANSCRIPTION
# 1141  PC2                      REACTOME_LEISHMANIA_INFECTION
# 1048  PC2  REACTOME_GLYCOSAMINOGLYCAN_PROTEIN_LINKAGE_REG...
# 1567  PC2                           REACTOME_UCH_PROTEINASES
# 1173  PC2   REACTOME_MITOCHONDRIAL_FATTY_ACID_BETA_OXIDATION
# 831   PC2                         REACTOME_ATTENUATION_PHASE
# 977   PC2         REACTOME_EARLY_SARS_COV_2_INFECTION_EVENTS
# 1243  PC2            REACTOME_OVARIAN_TUMOR_DOMAIN_PROTEASES
# 1430  PC2  REACTOME_SIGNALING_BY_CSF1_M_CSF_IN_MYELOID_CELLS
# 1010  PC2       REACTOME_FC_EPSILON_RECEPTOR_FCERI_SIGNALING
# 1155  PC2  REACTOME_METABOLIC_DISORDERS_OF_BIOLOGICAL_OXI...
# 1055  PC2          REACTOME_GPVI_MEDIATED_ACTIVATION_CASCADE
#
#       pearson_mean_abs_r  pearson_median_abs_r  pearson_min_abs_r  \
# 1468            0.574773              0.516309           0.461192
# 823             0.434634              0.479960           0.153729
# 855             0.499300              0.481970           0.274181
# 1024            0.415396              0.253318           0.123416
# 861             0.367993              0.401709           0.074735
# 917             0.400718              0.158422           0.028370
# 1170            0.418732              0.427511           0.127697
# 1169            0.472715              0.440410           0.290073
# 1104            0.495519              0.390553           0.224675
# 1075            0.411043              0.489249           0.063085
# 1374            0.428080              0.407180           0.263133
# 1480            0.392191              0.365527           0.064840
# 1047            0.391411              0.385908           0.204035
# 1392            0.462946              0.393417           0.225572
# 918             0.428857              0.190170           0.143011
# 1210            0.385677              0.437535           0.083437
# 915             0.393675              0.274739           0.170606
# 1138            0.425238              0.413734           0.272509
# 1308            0.437854              0.468997           0.214321
# 1141            0.424799              0.386333           0.119998
# 1048            0.414586              0.329988           0.161024
# 1567            0.273514              0.237291           0.026212
# 1173            0.403664              0.464093           0.112034
# 831             0.464834              0.662740           0.004322
# 977             0.435071              0.415408           0.270127
# 1243            0.391179              0.390571           0.143964
# 1430            0.380938              0.286249           0.055695
# 1010            0.410928              0.381259           0.256588
# 1155            0.348912              0.357613           0.062588
# 1055            0.537829              0.498087           0.246939
#
#       pearson_max_abs_r  spearman_mean_abs_r  spearman_median_abs_r  \
# 1468           0.774497             0.577576               0.660606
# 823            0.569800             0.540000               0.545455
# 855            0.753076             0.503030               0.500000
# 1024           0.796729             0.500606               0.345455
# 861            0.617684             0.496970               0.527273
# 917            0.884269             0.491515               0.381818
# 1170           0.756171             0.473939               0.466667
# 1169           0.715812             0.472121               0.442424
# 1104           0.797647             0.470909               0.472727
# 1075           0.578344             0.470303               0.481818
# 1374           0.735013             0.468485               0.509091
# 1480           0.662867             0.465455               0.369697
# 1047           0.715056             0.463636               0.381818
# 1392           0.843226             0.455758               0.427273
# 918            0.867467             0.443030               0.418182
# 1210           0.603829             0.440000               0.466667
# 915            0.745950             0.438788               0.454545
# 1138           0.638693             0.436970               0.454545
# 1308           0.582299             0.435152               0.463636
# 1141           0.815324             0.434545               0.490909
# 1048           0.667571             0.432121               0.515152
# 1567           0.553317             0.431515               0.357576
# 1173           0.623124             0.429697               0.430303
# 831            0.717140             0.428485               0.539394
# 977            0.579250             0.427879               0.442424
# 1243           0.615860             0.427273               0.409091
# 1430           0.823350             0.426061               0.381818
# 1010           0.582375             0.422424               0.354545
# 1155           0.654923             0.421818               0.478788
# 1055           0.800197             0.421212               0.296970
#
#       spearman_min_abs_r  spearman_max_abs_r  n_folds
# 1468            0.318182            0.818182        5
# 823             0.463636            0.672727        5
# 855             0.357576            0.709091        5
# 1024            0.236364            0.866667        5
# 861             0.224242            0.727273        5
# 917             0.115152            0.878788        5
# 1170            0.263636            0.696970        5
# 1169            0.190909            0.793939        5
# 1104            0.127273            0.721212        5
# 1075            0.175758            0.806061        5
# 1374            0.151515            0.757576        5
# 1480            0.200000            0.806061        5
# 1047            0.333333            0.818182        5
# 1392            0.248485            0.781818        5
# 918             0.066667            0.830303        5
# 1210            0.127273            0.600000        5
# 915             0.027273            0.718182        5
# 1138            0.260606            0.627273        5
# 1308            0.139394            0.648485        5
# 1141            0.154545            0.709091        5
# 1048            0.027273            0.769697        5
# 1567            0.218182            0.721212        5
# 1173            0.163636            0.672727        5
# 831             0.006061            0.736364        5
# 977             0.100000            0.684848        5
# 1243            0.109091            0.709091        5
# 1430            0.030303            0.881818        5
# 1010            0.321212            0.600000        5
# 1155            0.163636            0.536364        5
# 1055            0.118182            0.757576        5

# %%
cross_tissue_to_plasma[
    cross_tissue_to_plasma["PC"] == "PC2"
].sort_values(
    ["pearson_fdr",'spearman_r'],
    ascending=True
).head(50)
# Out:
#        PC                                            pathway   n  pearson_r  \
# 2502  PC2                         REACTOME_SIGNALING_BY_VEGF  10  -0.976303
# 2902  PC2  REACTOME_CLASS_I_MHC_MEDIATED_ANTIGEN_PROCESSI...  10  -0.971598
# 3036  PC2                REACTOME_NERVOUS_SYSTEM_DEVELOPMENT  10  -0.967378
# 2940  PC2  REACTOME_DISEASES_OF_SIGNAL_TRANSDUCTION_BY_GR...  10  -0.967011
# 1095  PC2                      REACTOME_INTERFERON_SIGNALING  11  -0.953240
# 2864  PC2     REACTOME_ANTIGEN_PROCESSING_CROSS_PRESENTATION  10  -0.964607
# 1703  PC2              REACTOME_GLYCOSAMINOGLYCAN_METABOLISM  10  -0.959713
# 412   PC2                   REACTOME_ELASTIC_FIBRE_FORMATION  11  -0.946442
# 965   PC2  REACTOME_ANTIMICROBIAL_MECHANISM_OF_IFN_STIMUL...  11  -0.942812
# 1152  PC2       REACTOME_PLATELET_AGGREGATION_PLUG_FORMATION  11  -0.947603
# 3137  PC2                          REACTOME_SIGNALING_BY_WNT  10  -0.957197
# 3145  PC2                             REACTOME_TCR_SIGNALING  10  -0.961474
# 3013  PC2            REACTOME_MAPK_FAMILY_SIGNALING_CASCADES  10  -0.957214
# 2882  PC2    REACTOME_BETA_CATENIN_INDEPENDENT_WNT_SIGNALING  10  -0.960048
# 2987  PC2          REACTOME_HOST_INTERACTIONS_OF_HIV_FACTORS  10  -0.957157
# 3053  PC2  REACTOME_PLATELET_ACTIVATION_SIGNALING_AND_AGG...  10  -0.959373
# 2931  PC2                          REACTOME_DEUBIQUITINATION  10  -0.962079
# 1859  PC2                        REACTOME_SIGNALING_BY_NTRKS  10   0.958101
# 3094  PC2                         REACTOME_RHOD_GTPASE_CYCLE  10  -0.956124
# 494   PC2  REACTOME_MOLECULES_ASSOCIATED_WITH_ELASTIC_FIBRES  11  -0.939517
# 3163  PC2          REACTOME_UB_SPECIFIC_PROCESSING_PROTEASES  10  -0.953971
# 1106  PC2                        REACTOME_L1CAM_INTERACTIONS  11  -0.937748
# 2894  PC2                   REACTOME_CELL_CELL_COMMUNICATION  10  -0.953097
# 1254  PC2  REACTOME_TRANSLOCATION_OF_SLC2A4_GLUT4_TO_THE_...  11  -0.935856
# 2892  PC2      REACTOME_CELLULAR_RESPONSE_TO_CHEMICAL_STRESS  10  -0.952112
# 1167  PC2  REACTOME_RECRUITMENT_OF_NUMA_TO_MITOTIC_CENTRO...  11  -0.931798
# 3034  PC2                               REACTOME_NEDDYLATION  10  -0.949474
# 977   PC2                  REACTOME_AURKA_ACTIVATION_BY_TPX2  11  -0.928234
# 1134  PC2                REACTOME_NERVOUS_SYSTEM_DEVELOPMENT  11  -0.927580
# 1166  PC2  REACTOME_RECRUITMENT_OF_MITOTIC_CENTROSOME_PRO...  11  -0.928234
# 1127  PC2                      REACTOME_MITOTIC_PROMETAPHASE  11  -0.930357
# 1205  PC2                      REACTOME_SARS_COV_1_INFECTION  11  -0.927275
# 2986  PC2                             REACTOME_HIV_INFECTION  10  -0.944312
# 3055  PC2   REACTOME_POST_TRANSLATIONAL_PROTEIN_MODIFICATION  10  -0.944776
# 3050  PC2                            REACTOME_PCP_CE_PATHWAY  10  -0.945948
# 3077  PC2  REACTOME_REGULATION_OF_MRNA_STABILITY_BY_PROTE...  10  -0.944325
# 1620  PC2                        REACTOME_CDC42_GTPASE_CYCLE  10   0.946483
# 1854  PC2                 REACTOME_SIGNALING_BY_INTERLEUKINS  10   0.944013
# 1053  PC2  REACTOME_FACTORS_INVOLVED_IN_MEGAKARYOCYTE_DEV...  11  -0.925801
# 2949  PC2           REACTOME_EPHB_MEDIATED_FORWARD_SIGNALING  10  -0.941772
# 1094  PC2                        REACTOME_INTEGRIN_SIGNALING  11  -0.924708
# 3027  PC2                    REACTOME_MITOTIC_G2_G2_M_PHASES  10  -0.941484
# 392   PC2  REACTOME_DENGUE_VIRUS_GENOME_TRANSLATION_AND_R...  11   0.922343
# 3061  PC2                           REACTOME_PTEN_REGULATION  10  -0.938025
# 984   PC2  REACTOME_CARGO_TRAFFICKING_TO_THE_PERICILIARY_...  11  -0.919234
# 2896  PC2                    REACTOME_CELL_CYCLE_CHECKPOINTS  10  -0.937473
# 2865  PC2  REACTOME_ANTIGEN_PROCESSING_UBIQUITINATION_PRO...  10  -0.937225
# 1669  PC2                 REACTOME_DISEASES_OF_GLYCOSYLATION  10  -0.936296
# 3080  PC2  REACTOME_REGULATION_OF_PD_L1_CD274_POST_TRANSL...  10  -0.936643
# 3117  PC2           REACTOME_SEPARATION_OF_SISTER_CHROMATIDS  10  -0.936359
#
#       pearson_p  spearman_r  spearman_p  fold  pearson_fdr  spearman_fdr
# 2502   0.000001   -0.842424    0.002220     3     0.000974      0.012567
# 2902   0.000003   -0.939394    0.000055     4     0.001012      0.003219
# 3036   0.000005   -0.830303    0.002940     4     0.001052      0.014406
# 2940   0.000005   -0.818182    0.003815     4     0.001052      0.016254
# 1095   0.000006   -0.881818    0.000330     1     0.001097      0.006260
# 2864   0.000007   -0.769697    0.009222     4     0.001097      0.026624
# 1703   0.000011   -0.963636    0.000007     2     0.001138      0.001289
# 412    0.000010   -0.936364    0.000022     0     0.001138      0.001853
# 965    0.000014   -0.927273    0.000040     1     0.001138      0.002930
# 1152   0.000009   -0.881818    0.000330     1     0.001138      0.006260
# 3137   0.000014   -0.854545    0.001637     4     0.001138      0.011063
# 3145   0.000009   -0.830303    0.002940     4     0.001138      0.014406
# 3013   0.000014   -0.806061    0.004862     4     0.001138      0.018705
# 2882   0.000011   -0.793939    0.006100     4     0.001138      0.021390
# 2987   0.000014   -0.757576    0.011143     4     0.001138      0.030013
# 3053   0.000011   -0.757576    0.011143     4     0.001138      0.030013
# 2931   0.000009   -0.733333    0.015801     4     0.001138      0.038382
# 1859   0.000013    0.951515    0.000023     2     0.001138      0.001853
# 3094   0.000015   -0.793939    0.006100     4     0.001189      0.021390
# 494    0.000018   -0.927273    0.000040     0     0.001266      0.002930
# 3163   0.000019   -0.709091    0.021666     4     0.001266      0.048538
# 1106   0.000020   -0.709091    0.014552     1     0.001297      0.036553
# 2894   0.000020   -0.709091    0.021666     4     0.001297      0.048538
# 1254   0.000023   -0.881818    0.000330     1     0.001344      0.006260
# 2892   0.000022   -0.866667    0.001174     4     0.001344      0.009466
# 1167   0.000030   -0.918182    0.000067     1     0.001478      0.003352
# 3034   0.000027   -0.757576    0.011143     4     0.001478      0.030013
# 977    0.000037   -0.963636    0.000002     1     0.001534      0.000839
# 1134   0.000039   -0.963636    0.000002     1     0.001534      0.000839
# 1166   0.000037   -0.963636    0.000002     1     0.001534      0.000839
# 1127   0.000033   -0.936364    0.000022     1     0.001534      0.001853
# 1205   0.000040   -0.936364    0.000022     1     0.001534      0.001853
# 2986   0.000039   -0.806061    0.004862     4     0.001534      0.018705
# 3055   0.000038   -0.757576    0.011143     4     0.001534      0.030013
# 3050   0.000035   -0.721212    0.018573     4     0.001534      0.042851
# 3077   0.000039   -0.696970    0.025097     4     0.001534      0.054083
# 1620   0.000034    0.927273    0.000112     2     0.001534      0.004036
# 1854   0.000040    0.939394    0.000055     2     0.001534      0.003219
# 1053   0.000043   -0.890909    0.000233     1     0.001575      0.005649
# 2949   0.000047   -0.878788    0.000814     4     0.001621      0.008012
# 1094   0.000046   -0.872727    0.000455     1     0.001621      0.006895
# 3027   0.000048   -0.830303    0.002940     4     0.001629      0.014406
# 392    0.000053    0.900000    0.000160     0     0.001750      0.004972
# 3061   0.000060   -0.781818    0.007547     4     0.001879      0.023852
# 984    0.000063   -0.872727    0.000455     1     0.001919      0.006895
# 2896   0.000062   -0.769697    0.009222     4     0.001919      0.026624
# 2865   0.000063   -0.745455    0.013330     4     0.001919      0.033996
# 1669   0.000067   -0.963636    0.000007     2     0.001957      0.001289
# 3080   0.000065   -0.709091    0.021666     4     0.001957      0.048538
# 3117   0.000066   -0.660606    0.037588     4     0.001957      0.075654

# %%
cross_tissue_to_plasma.columns
# Out:
# Index(['PC', 'pathway', 'n', 'pearson_r', 'pearson_p', 'spearman_r',
#        'spearman_p', 'fold', 'pearson_fdr', 'spearman_fdr'],
#       dtype='str')

# %%
cross_plasma_to_tissue[
    cross_plasma_to_tissue["PC"] == "PC2"
].sort_values(
    "pearson_r",
    ascending=True
).head(20)
# Out:
#        PC                                            pathway   n  pearson_r  \
# 7687  PC2                         REACTOME_RND2_GTPASE_CYCLE  10  -0.908319
# 917   PC2                        REACTOME_DAP12_INTERACTIONS  11  -0.884269
# 918   PC2                           REACTOME_DAP12_SIGNALING  11  -0.867467
# 7688  PC2                         REACTOME_RND3_GTPASE_CYCLE  10  -0.843226
# 2617  PC2                        REACTOME_GLUCOSE_METABOLISM  11  -0.834927
# 1014  PC2                            REACTOME_FLT3_SIGNALING  11  -0.824939
# 1430  PC2  REACTOME_SIGNALING_BY_CSF1_M_CSF_IN_MYELOID_CELLS  11  -0.823350
# 1335  PC2            REACTOME_REGULATION_OF_SIGNALING_BY_CBL  11  -0.797743
# 1104  PC2                        REACTOME_INTEGRIN_SIGNALING  11  -0.797647
# 7320  PC2  REACTOME_FORMATION_OF_THE_DYSTROPHIN_GLYCOPROT...  10  -0.796729
# 1055  PC2          REACTOME_GPVI_MEDIATED_ACTIVATION_CASCADE  11  -0.789239
# 1117  PC2  REACTOME_INTERLEUKIN_3_INTERLEUKIN_5_AND_GM_CS...  11  -0.785210
# 5694  PC2                  REACTOME_DOWNSTREAM_TCR_SIGNALING  10  -0.774031
# 1217  PC2                  REACTOME_NOD1_2_SIGNALING_PATHWAY  11  -0.770528
# 1116  PC2            REACTOME_INTERLEUKIN_2_FAMILY_SIGNALING  11  -0.761566
# 7103  PC2  REACTOME_ANCHORING_OF_THE_BASAL_BODY_TO_THE_PL...  10  -0.760113
# 7624  PC2  REACTOME_REGULATION_OF_PLK1_ACTIVITY_AT_G2_M_T...  10  -0.758824
# 7129  PC2                  REACTOME_AURKA_ACTIVATION_BY_TPX2  10  -0.756521
# 5577  PC2                   REACTOME_CD209_DC_SIGN_SIGNALING  10  -0.753076
# 1535  PC2       REACTOME_TRANSCRIPTIONAL_REGULATION_BY_RUNX3  11  -0.748241
#
#       pearson_p  spearman_r  spearman_p  fold  pearson_fdr  spearman_fdr
# 7687   0.000276   -0.939394    0.000055     4     0.593317      0.262128
# 917    0.000302   -0.809091    0.002559     0     0.593317      0.510981
# 918    0.000541   -0.809091    0.002559     0     0.709869      0.510981
# 7688   0.002177   -0.781818    0.007547     4     0.777489      0.535090
# 2617   0.001384   -0.709091    0.014552     1     0.777489      0.612431
# 1014   0.001775   -0.836364    0.001333     0     0.777489      0.476917
# 1430   0.001844   -0.881818    0.000330     0     0.777489      0.338028
# 1335   0.003260   -0.818182    0.002083     0     0.873036      0.510981
# 1104   0.003267   -0.700000    0.016471     0     0.873036      0.641716
# 7320   0.005797   -0.866667    0.001174     4     0.931096      0.461787
# 1055   0.003873   -0.745455    0.008455     0     0.896391      0.548625
# 1117   0.004191   -0.863636    0.000612     0     0.904254      0.370310
# 5694   0.008596   -0.696970    0.025097     3     0.982582      0.695562
# 1217   0.005515   -0.727273    0.011205     0     0.904254      0.558121
# 1116   0.006462   -0.790909    0.003746     0     0.972529      0.510981
# 7103   0.010720   -0.793939    0.006100     4     0.982582      0.510981
# 7624   0.010934   -0.818182    0.003815     4     0.982582      0.510981
# 7129   0.011323   -0.793939    0.006100     4     0.982582      0.510981
# 5577   0.011923   -0.709091    0.021666     3     0.982582      0.682043
# 1535   0.008082   -0.727273    0.011205     0     0.982582      0.558121
